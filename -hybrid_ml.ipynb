# %% [markdown]
# # Initialization

# %%
import numpy as np
import matplotlib.pyplot as plt
import matplotlib.image as mpimg
import pandas as pd
import pickle
import os
import time
import subprocess
import json
from tensorflow.keras import models, optimizers, callbacks
from tensorflow.keras.layers import Dense, BatchNormalization
import tensorflow as tf
from sklearn.preprocessing import StandardScaler
from sklearn.model_selection import train_test_split

# making plots beautiful:
SMALL_SIZE = 20//1.4
MEDIUM_SIZE = 24//1.4
BIGGER_SIZE = 28//1.4
plt.rc('font', size=SMALL_SIZE)         
plt.rc('axes', titlesize=MEDIUM_SIZE)    
plt.rc('axes', labelsize=MEDIUM_SIZE)   
plt.rc('xtick', labelsize=SMALL_SIZE)   
plt.rc('ytick', labelsize=SMALL_SIZE)   
plt.rc('legend', fontsize=SMALL_SIZE)   
plt.rc('figure', titlesize=BIGGER_SIZE)

# %% [markdown]
# # Data generation runtime

# %%
# Before running the follwing code, make sure to first generate all the datasets
# by numerical models. Here, the datasets are gathered to compare the runtimes.

time_lf_1 = np.loadtxt(os.path.join('gnn_datasets', 'Model-1', 'time_lf.csv'), delimiter=",", dtype='float32')
time_hf_1 = np.loadtxt(os.path.join('gnn_datasets', 'Model-1', 'time_hf.csv'), delimiter=",", dtype='float32')
time_lf_2 = np.loadtxt(os.path.join('gnn_datasets', 'Model-2', 'time_lf.csv'), delimiter=",", dtype='float32')
time_hf_2 = np.loadtxt(os.path.join('gnn_datasets', 'Model-2', 'time_hf.csv'), delimiter=",", dtype='float32')
time_lf_2d = np.concatenate((time_lf_1, time_lf_2))
time_hf_2d = np.concatenate((time_hf_1, time_hf_2))
time_2d = (time_hf_2d - time_lf_2d) / time_lf_2d

time_hf_3d = np.loadtxt('time_input_3d.csv', delimiter=",", dtype='float32')
time_lf_3d = np.loadtxt('time_output_3d_lowfidelity.csv', delimiter=",", dtype='float32')
time_3d = (time_hf_3d - time_lf_3d) / time_lf_3d

plt.clf()

data = [time_2d, time_3d]

plt.figure(figsize=(6, 5))

labels = ['2D simulation', '3D simulation']

plt.violinplot(data, showmeans=False, showmedians=True)
plt.xticks(np.arange(1, len(labels)+1), labels, fontsize=MEDIUM_SIZE)

plt.ylim(0, np.max(np.concatenate(data, axis = -1))+0.5)
plt.ylabel('Relative runtime decrease')

plt.gca().set_yticklabels(['{:.0f}%'.format(x*100) for x in plt.gca().get_yticks()]) 
plt.tight_layout()
plt.savefig('comparison.pdf', format='pdf', dpi=500)
# Out:
# C:\ProgramData\Anaconda3\envs\MeshGraphNet\lib\site-packages\ipykernel_launcher.py:30: UserWarning: FixedFormatter should only be used together with FixedLocator

# %%
# Now, we show them in a table.

def sec_fn(x):
    '''A helper funtion to show the seconds.'''
    if x >= 60:
        minute = int(x // 60)
        return str(int(x - minute*60))
    else:
        return str(int(x))

def min_fn(x):
    '''A helper funtion to show the minutes.'''
    if x >= 60:
       minute = int(x // 60)
       return str(minute)
    else:
      return str('0')

# vectorize is used to apply all funtions on each element
min_fn = np.vectorize(min_fn)
sec_fn = np.vectorize(sec_fn)

# for concatation we need to reshape them.
min_hf_2d = min_fn(time_hf_2d.T).reshape((time_hf_2d.shape[0],1))
min_lf_2d = min_fn(time_lf_2d.T).reshape((time_lf_2d.shape[0],1))
sec_hf_2d = sec_fn(time_hf_2d.T).reshape((time_hf_2d.shape[0],1))
sec_lf_2d = sec_fn(time_lf_2d.T).reshape((time_lf_2d.shape[0],1))
data = np.concatenate([min_lf_2d, sec_lf_2d, min_hf_2d, sec_hf_2d], axis = -1)

multi_index = pd.MultiIndex.from_tuples([("LF", "Min"),
                                      ("LF", "Sec"),
                                      ("HF", "Min"),
                                      ("HF", "Sec"),],
                                      names=['Model type','Runtime'])

index_2d = ['2D sample '+str(i) for i in range(1,len(time_hf_2d)+1)]
df_2d = pd.DataFrame(data, index = index_2d, columns = multi_index)


# And for the 3d model:
min_hf_3d = min_fn(time_hf_3d.T).reshape((time_hf_3d.shape[0],1))
min_lf_3d = min_fn(time_lf_3d.T).reshape((time_lf_3d.shape[0],1))
sec_hf_3d = sec_fn(time_hf_3d.T).reshape((time_hf_3d.shape[0],1))
sec_lf_3d = sec_fn(time_lf_3d.T).reshape((time_lf_3d.shape[0],1))
data = np.concatenate([min_lf_3d, sec_lf_3d, min_hf_3d, sec_hf_3d], axis = -1)

index_3d = ['3D sample '+str(i) for i in range(1,len(time_hf_3d)+1)]
df_3d = pd.DataFrame(data, index = index_3d, columns = multi_index)

print(pd.concat([df_2d, df_3d]).to_latex())
# Out:
# \begin{tabular}{lllll}
# \toprule
# Model type & \multicolumn{2}{l}{LF} & \multicolumn{2}{l}{HF} \\
# Runtime & Min & Sec & Min & Sec \\
# \midrule
# 2D sample 1   &   0 &  21 &   2 &  21 \\
# 2D sample 2   &   0 &  21 &   2 &  21 \\
# 2D sample 3   &   0 &  21 &   2 &  21 \\
# 2D sample 4   &   0 &  21 &   2 &  21 \\
# 2D sample 5   &   0 &  21 &   2 &  21 \\
# 2D sample 6   &   0 &  21 &   2 &  21 \\
# 2D sample 7   &   0 &  21 &   2 &  20 \\
# 2D sample 8   &   0 &  21 &   2 &  19 \\
# 2D sample 9   &   0 &  21 &   2 &  22 \\
# 2D sample 10  &   0 &  21 &   2 &  21 \\
# 2D sample 11  &   0 &  21 &   2 &  21 \\
# 2D sample 12  &   0 &  21 &   2 &  21 \\
# 2D sample 13  &   0 &  21 &   2 &  21 \\
# 2D sample 14  &   0 &  21 &   2 &  21 \\
# 2D sample 15  &   0 &  21 &   2 &  21 \\
# 2D sample 16  &   0 &  21 &   2 &  21 \\
# 2D sample 17  &   0 &  21 &   2 &  21 \\
# 2D sample 18  &   0 &  21 &   2 &  22 \\
# 2D sample 19  &   0 &  21 &   2 &  21 \\
# 2D sample 20  &   0 &  21 &   2 &  22 \\
# 2D sample 21  &   0 &  21 &   2 &  21 \\
# 2D sample 22  &   0 &  21 &   2 &  22 \\
# 2D sample 23  &   0 &  21 &   2 &  22 \\
# 2D sample 24  &   0 &  21 &   2 &  22 \\
# 2D sample 25  &   0 &  21 &   2 &  22 \\
# 2D sample 26  &   0 &  21 &   2 &  21 \\
# 2D sample 27  &   0 &  21 &   2 &  21 \\
# 2D sample 28  &   0 &  21 &   2 &  22 \\
# 2D sample 29  &   0 &  21 &   2 &  22 \\
# 2D sample 30  &   0 &  21 &   2 &  22 \\
# 2D sample 31  &   0 &  24 &   2 &  11 \\
# 2D sample 32  &   0 &  18 &   2 &  10 \\
# 2D sample 33  &   0 &  18 &   2 &  10 \\
# 2D sample 34  &   0 &  18 &   2 &  10 \\
# 2D sample 35  &   0 &  18 &   2 &  10 \\
# 2D sample 36  &   0 &  19 &   2 &  11 \\
# 2D sample 37  &   0 &  18 &   2 &  11 \\
# 2D sample 38  &   0 &  18 &   1 &  51 \\
# 2D sample 39  &   0 &  18 &   2 &  10 \\
# 2D sample 40  &   0 &  18 &   2 &  11 \\
# 3D sample 1   &   1 &  22 &  10 &  22 \\
# 3D sample 2   &   1 &   5 &   7 &  31 \\
# 3D sample 3   &   1 &   1 &   7 &  37 \\
# 3D sample 4   &   1 &  51 &  14 &  23 \\
# 3D sample 5   &   1 &   9 &  11 &  53 \\
# 3D sample 6   &   1 &   7 &  11 &  40 \\
# 3D sample 7   &   1 &  19 &   9 &  54 \\
# 3D sample 8   &   1 &  11 &  12 &   2 \\
# 3D sample 9   &   1 &  31 &   9 &   2 \\
# 3D sample 10  &   1 &  23 &  12 &  19 \\
# 3D sample 11  &   1 &   3 &   7 &  11 \\
# 3D sample 12  &   1 &  15 &  11 &  27 \\
# 3D sample 13  &   1 &  23 &   8 &  37 \\
# 3D sample 14  &   1 &  53 &  14 &  22 \\
# 3D sample 15  &   1 &  13 &   7 &  15 \\
# 3D sample 16  &   1 &  25 &  14 &  50 \\
# 3D sample 17  &   1 &   5 &   4 &   2 \\
# 3D sample 18  &   1 &  17 &  11 &  40 \\
# 3D sample 19  &   1 &   7 &   7 &  29 \\
# 3D sample 20  &   1 &   5 &   7 &  18 \\
# 3D sample 21  &   0 &  59 &   7 &  25 \\
# 3D sample 22  &   2 &   3 &  20 &  48 \\
# 3D sample 23  &   1 &  15 &  12 &  36 \\
# 3D sample 24  &   1 &  29 &   9 &  57 \\
# 3D sample 25  &   1 &  11 &   7 &  20 \\
# 3D sample 26  &   1 &  21 &  12 &  14 \\
# 3D sample 27  &   1 &  17 &   7 &  13 \\
# 3D sample 28  &   1 &   5 &   8 &   7 \\
# 3D sample 29  &   1 &  23 &  13 &  50 \\
# 3D sample 30  &   1 &  11 &  12 &  58 \\
# 3D sample 31  &   1 &   0 &   7 &  55 \\
# 3D sample 32  &   2 &  13 &  17 &  15 \\
# 3D sample 33  &   1 &   7 &   7 &  53 \\
# 3D sample 34  &   1 &  25 &  15 &  43 \\
# 3D sample 35  &   1 &   5 &   7 &  42 \\
# 3D sample 36  &   1 &   9 &   7 &  25 \\
# 3D sample 37  &   1 &   9 &  10 &  30 \\
# 3D sample 38  &   1 &   3 &   4 &  18 \\
# 3D sample 39  &   1 &  19 &  10 &   5 \\
# 3D sample 40  &   1 &  23 &  14 &  18 \\
# 3D sample 41  &   1 &  11 &  10 &  58 \\
# 3D sample 42  &   1 &  17 &   7 &  55 \\
# 3D sample 43  &   1 &  13 &  11 &  52 \\
# 3D sample 44  &   1 &  29 &  15 &  39 \\
# 3D sample 45  &   1 &  13 &  13 &  14 \\
# 3D sample 46  &   1 &   7 &   4 &  36 \\
# 3D sample 47  &   1 &  17 &  19 &  32 \\
# 3D sample 48  &   1 &  19 &  10 &  28 \\
# 3D sample 49  &   1 &   3 &   7 &  35 \\
# 3D sample 50  &   1 &   7 &   4 &  14 \\
# 3D sample 51  &   1 &  21 &  14 &   1 \\
# 3D sample 52  &   1 &  21 &  12 &  36 \\
# 3D sample 53  &   1 &  43 &  13 &  10 \\
# 3D sample 54  &   1 &  23 &  15 &   5 \\
# 3D sample 55  &   1 &   4 &   9 &   5 \\
# 3D sample 56  &   1 &  23 &  13 &  38 \\
# 3D sample 57  &   2 &   3 &  21 &  21 \\
# 3D sample 58  &   1 &  21 &   9 &  39 \\
# 3D sample 59  &   1 &  17 &  10 &  17 \\
# 3D sample 60  &   1 &   7 &   7 &  25 \\
# 3D sample 61  &   1 &   7 &   8 &  29 \\
# 3D sample 62  &   1 &   3 &   8 &  48 \\
# 3D sample 63  &   1 &  53 &  14 &  19 \\
# 3D sample 64  &   1 &  19 &   9 &   4 \\
# 3D sample 65  &   1 &  51 &  13 &  52 \\
# 3D sample 66  &   1 &  43 &  15 &   7 \\
# 3D sample 67  &   1 &  15 &  13 &  25 \\
# 3D sample 68  &   1 &   9 &  11 &  31 \\
# 3D sample 69  &   1 &   7 &   7 &  23 \\
# 3D sample 70  &   1 &  33 &  13 &   3 \\
# 3D sample 71  &   1 &  17 &  18 &  24 \\
# 3D sample 72  &   1 &  43 &  13 &  36 \\
# 3D sample 73  &   1 &  21 &   9 &  36 \\
# 3D sample 74  &   1 &  15 &   9 &  18 \\
# 3D sample 75  &   1 &   3 &   7 &  40 \\
# 3D sample 76  &   1 &  23 &  12 &  21 \\
# 3D sample 77  &   1 &  11 &  10 &  10 \\
# 3D sample 78  &   1 &  19 &   9 &  50 \\
# 3D sample 79  &   2 &   5 &  13 &   1 \\
# 3D sample 80  &   1 &  17 &   9 &   8 \\
# 3D sample 81  &   1 &  21 &  12 &  17 \\
# 3D sample 82  &   1 &  39 &  14 &  36 \\
# 3D sample 83  &   1 &   7 &  11 &  31 \\
# 3D sample 84  &   1 &  37 &  13 &   3 \\
# 3D sample 85  &   1 &   7 &   7 &   8 \\
# 3D sample 86  &   1 &  23 &   9 &  42 \\
# 3D sample 87  &   2 &  17 &  15 &  32 \\
# 3D sample 88  &   1 &  17 &   8 &  42 \\
# 3D sample 89  &   1 &  13 &   9 &  58 \\
# 3D sample 90  &   1 &  19 &   8 &  34 \\
# 3D sample 91  &   1 &   5 &   3 &  54 \\
# 3D sample 92  &   1 &   5 &   8 &  28 \\
# 3D sample 93  &   1 &   7 &   7 &   7 \\
# 3D sample 94  &   1 &   9 &  10 &  37 \\
# 3D sample 95  &   1 &  11 &   9 &  54 \\
# 3D sample 96  &   1 &   5 &   7 &   7 \\
# 3D sample 97  &   1 &   1 &   8 &   8 \\
# 3D sample 98  &   2 &  11 &  15 &   8 \\
# 3D sample 99  &   1 &   1 &   8 &   2 \\
# 3D sample 100 &   1 &   2 &   4 &   6 \\
# \bottomrule
# \end{tabular}

# %% [markdown]
# # 2D Simulation

# %%
# Alls the datasets are continuesly converted to tfrecords for the graph models by this class.

BytesList = tf.train.BytesList
Feature = tf.train.Feature
Features = tf.train.Features
Example = tf.train.Example

class db_convertor():
    '''This class is used to first set aside a valid set, then from the
    remainings each time different group of training sets are saved for
    training with different numbers of samples by save_tfrecords.'''
    def __init__(self, ModelName):
        
        self.dir_address = os.path.join("gnn_datasets", ModelName)
        os.chdir(self.dir_address)

        # meta files contains important information to properly import serialized csv files.
        with open("meta.json", "r") as f: meta = json.load(f)
        
        features = {}
        for field_name in meta["field_names"]:
            dtype = meta["features"][field_name]["dtype"]
            features[field_name] = np.loadtxt(field_name + ".csv", delimiter = ",", dtype=dtype)
            
            # it is important to correct the types of the files to prevent errors of the graph model.
            if dtype=='float64':
                features[field_name] = features[field_name].astype('float32')
                meta["features"][field_name]["dtype"] = 'float32'
            
            # Abaqus cell indecies starts from 1 instead of 0.
            if field_name == "cells": features[field_name] -= 1
            
            # adding only the first axis:
            features[field_name] = features[field_name].reshape(meta["total_num_samples"], -1)
    
        np.random.seed(40)
        np.random.shuffle(features[field_name])
        
        self.features = features
        
        with open("meta.json", "w") as f: json.dump(meta, f, indent=2, separators=(", ", ": "))

        self.meta = meta

        os.chdir("..\..")

    def save_tfrecords(self, key, sliceList = None, resetAddress = True):
        
        os.chdir(self.dir_address)
        if sliceList == None: sliceList = [0, self.meta["total_num_samples"]]
        
        features = self.features
        meta = self.meta
    
        with tf.io.TFRecordWriter(key+".tfrecord") as f:
            for array_slice_key in range(sliceList[0],sliceList[1]):
                temp = {feature_key: Feature(bytes_list=BytesList(
                            value=[features[feature_key][array_slice_key].tobytes()]))
                            for feature_key in meta["field_names"]}
                person_example = Example(features=Features(feature=temp))
                
                f.write(person_example.SerializeToString())
        
        os.chdir("..\..")

# %%
def perform_2d_experiment(experiment_id, latent_size, num_layers, message_passing_steps, n_initial_steps,
                          num_training_steps, learning_rate, only_evaluate=False):
    '''This function performs training and evaluation for all surrogate models
    but without changing the training and evaluation sets.'''

    def run_2d(db_key, name, checkpoint_folder, dataset_folder, input_hf, input_nodal_disp,
             input_fixed_nodes, input_mat, n_initial_steps=None, num_training_steps=None):
        '''This funtion calls and runs gnn.py, containing the graph-based model.'''

        cmd = ["conda", "activate", "meshgraphnet", "&&", "python", "gnn.py", str(latent_size), str(num_layers),
               str(message_passing_steps), db_key, name, checkpoint_folder+"_"+experiment_id, dataset_folder, 
               str(input_hf), str(input_nodal_disp), str(input_fixed_nodes), str(input_mat)]
        
        if n_initial_steps != None:
            if num_training_steps == None:
                raise Exception("Error: define both num_training_steps and n_initial_steps together")
          
            cmd.extend([str(n_initial_steps), str(num_training_steps), str(learning_rate)])
        
        print(subprocess.getoutput(cmd))
    
    # these lists are gradually filled with different values passed into gnn.py. 
    db_key_list=[]              
    name_list=[]              
    checkpoint_folder_list=[] 
    dataset_folder_list=[]    
    input_hf_list=[]
    input_nodal_disp_list=[]
    input_fixed_nodes_list=[]
    input_mat_list=[]
    n_initial_steps_list=[]   
    num_training_steps_list=[]
    
    def append_list(db_key, name, checkpoint_folder, dataset_folder, input_hf, input_nodal_disp,
                    input_fixed_nodes, input_mat, n_initial_steps=None, num_training_steps=None):
        '''a helper funtion to append elements of the above lists'''
        db_key_list.append(db_key)              
        name_list.append(name)              
        checkpoint_folder_list.append(checkpoint_folder) 
        dataset_folder_list.append(dataset_folder)    
        input_hf_list.append(input_hf)
        input_nodal_disp_list.append(input_nodal_disp)    
        input_fixed_nodes_list.append(input_fixed_nodes)            
        input_mat_list.append(input_mat)         
        n_initial_steps_list.append(n_initial_steps)   
        num_training_steps_list.append(num_training_steps)
    
    # append values for training of the ML model
    append_list(db_key="train",
                name="ml",
                checkpoint_folder="ML model",
                dataset_folder="model-1",
                input_hf=False,
                input_nodal_disp=True,
                input_fixed_nodes=True,
                input_mat=True,
                n_initial_steps=n_initial_steps,
                num_training_steps=num_training_steps)
    
    # append values for training of the HML model
    append_list(db_key="train",
                name="hml",
                checkpoint_folder="HML model",
                dataset_folder="model-1",
                input_hf=False,
                input_nodal_disp=False,
                input_fixed_nodes=False,
                input_mat=False,
                n_initial_steps=n_initial_steps,
                num_training_steps=num_training_steps)
    
    # append values for training of the HML model with HF inputs
    append_list(db_key="train",
                name="hml",
                checkpoint_folder="HML model (with HF inputs)",
                dataset_folder="model-1",
                input_hf=True,
                input_nodal_disp=False,
                input_fixed_nodes=False,
                input_mat=False,
                n_initial_steps=n_initial_steps,
                num_training_steps=num_training_steps)
    
    # Now, for evaluation we use the above updated list first and the below lists
    # used to iterate on their currect values to define evaluation arguments for each.
    name_list_temp = name_list[:]
    checkpoint_folder_list_temp = checkpoint_folder_list[:]
    input_hf_list_temp = input_hf_list[:]
    input_nodal_disp_list_temp = input_nodal_disp_list[:]
    input_fixed_nodes_list_temp = input_fixed_nodes_list[:]
    input_mat_list_temp = input_mat_list[:]
    
    for db_key, dataset_folder in zip(["train", "valid", "test"], ["model-1", "model-1", "model-2"]):
        for (name, checkpoint_folder, input_hf, input_nodal_disp, input_fixed_nodes,
             input_mat) in zip(name_list_temp, checkpoint_folder_list_temp, input_hf_list_temp,
             input_nodal_disp_list_temp, input_fixed_nodes_list_temp, input_mat_list_temp):
          
            append_list(db_key=db_key,
                        name=name,
                        checkpoint_folder=checkpoint_folder,
                        dataset_folder=dataset_folder,
                        input_hf=input_hf,
                        input_nodal_disp=input_nodal_disp,
                        input_fixed_nodes=input_fixed_nodes,
                        input_mat=input_mat)
    
    # Now we run the loop one each group of passed values
    for (db_key, name, checkpoint_folder, dataset_folder, input_hf, input_nodal_disp,
         input_fixed_nodes, input_mat, n_initial_steps, num_training_steps) in zip(db_key_list,
         name_list, checkpoint_folder_list, dataset_folder_list, input_hf_list, input_nodal_disp_list, 
         input_fixed_nodes_list, input_mat_list, n_initial_steps_list, num_training_steps_list):
        
        # if you prefer to only evaluate currently trained models use this condition.
        if (n_initial_steps!=None and only_evaluate==True): continue
        
        run_2d(db_key, name, checkpoint_folder, dataset_folder, input_hf, input_nodal_disp,
               input_fixed_nodes, input_mat, n_initial_steps, num_training_steps)
    
    return checkpoint_folder_list, n_initial_steps_list

# %%
def run_2d_experiments_on_samples(data_name = "data_2d",
                                  sampleList = [4,9,14,20],
                                  latent_size=40,
                                  num_layers=3,
                                  message_passing_steps=3,
                                  n_initial_steps=400,
                                  num_training_steps=10000,
                                  learning_rate=1e-4,
                                  only_evaluate=False):
    '''This funtion first defines different numbers of samples and save
    training datasets. Next, it runs the training or evaulation for them
    using the perform_2d_experiment funtion. The returned values are saved
    in a dictionary.'''

    data = {}
    model_1_db = db_convertor("model-1")
    model_1_db.save_tfrecords("valid", [20,30])
    model_2_db = db_convertor("model-2")
    model_2_db.save_tfrecords("test", [0,10])
    for n_samples in sampleList:
        experiment_id = "%s_%s"%(n_samples, num_training_steps)
        data[experiment_id] = {}
        model_1_db.save_tfrecords("train", [0, n_samples])
        
        a, b = perform_2d_experiment(experiment_id, latent_size=latent_size, num_layers=num_layers,
                                     message_passing_steps=message_passing_steps, n_initial_steps=n_initial_steps,
                                     num_training_steps=num_training_steps, only_evaluate=only_evaluate,
                                     learning_rate=learning_rate)
        
        checkpoint_folder_list = [checkpoint_folder+"_"+experiment_id for checkpoint_folder in a]
        data[experiment_id]["checkpoint_folder_list"] = checkpoint_folder_list
        data[experiment_id]["n_initial_steps_list"] = b
    
    with open(data_name, 'wb') as f: pickle.dump(data, f)

# %%
# 2D model 1:

run_2d_experiments_on_samples(data_name = "data_2d_1",
                              n_initial_steps=100,
                              num_training_steps=1000,
                              learning_rate=1e-3)
# Out:
# 2022-04-09 13:05:52.273675: W tensorflow/stream_executor/platform/default/dso_loader.cc:55] Could not load dynamic library 'cudart64_100.dll'; dlerror: cudart64_100.dll not found
# 2022-04-09 13:05:52.273865: I tensorflow/stream_executor/cuda/cudart_stub.cc:29] Ignore above cudart dlerror if you do not have a GPU set up on your machine.
# WARNING:tensorflow:From C:\ProgramData\Anaconda3\envs\meshgraphnet\lib\site-packages\tensorflow_core\python\ops\resource_variable_ops.py:1630: calling BaseResourceVariable.__init__ (from tensorflow.python.ops.resource_variable_ops) with constraint is deprecated and will be removed in a future version.
# Instructions for updating:
# If using Keras pass *_constraint arguments to layers.
# WARNING:tensorflow:From C:\ProgramData\Anaconda3\envs\meshgraphnet\lib\site-packages\tensorflow_core\python\data\util\random_seed.py:58: where (from tensorflow.python.ops.array_ops) is deprecated and will be removed in a future version.
# Instructions for updating:
# Use tf.where in 2.0, which has the same broadcast rule as np.where
# WARNING:tensorflow:From C:\ProgramData\Anaconda3\envs\meshgraphnet\lib\site-packages\sonnet\python\modules\basic.py:127: calling TruncatedNormal.__init__ (from tensorflow.python.ops.init_ops) with dtype is deprecated and will be removed in a future version.
# Instructions for updating:
# Call initializer instance with the dtype argument instead of passing it to the constructor
# WARNING:tensorflow:From C:\ProgramData\Anaconda3\envs\meshgraphnet\lib\site-packages\sonnet\python\modules\basic.py:132: calling Zeros.__init__ (from tensorflow.python.ops.init_ops) with dtype is deprecated and will be removed in a future version.
# Instructions for updating:
# Call initializer instance with the dtype argument instead of passing it to the constructor
# WARNING:tensorflow:From C:\ProgramData\Anaconda3\envs\meshgraphnet\lib\site-packages\tensorflow_core\python\training\training_util.py:236: Variable.initialized_value (from tensorflow.python.ops.variables) is deprecated and will be removed in a future version.
# Instructions for updating:
# Use Variable.read_value. Variables in 2.X are initialized automatically both in eager and graph (inside tf.defun) contexts.
# 2022-04-09 13:05:59.613882: W tensorflow/stream_executor/platform/default/dso_loader.cc:55] Could not load dynamic library 'nvcuda.dll'; dlerror: nvcuda.dll not found
# 2022-04-09 13:05:59.614107: E tensorflow/stream_executor/cuda/cuda_driver.cc:318] failed call to cuInit: UNKNOWN ERROR (303)
# 2022-04-09 13:05:59.616939: I tensorflow/stream_executor/cuda/cuda_diagnostics.cc:169] retrieving CUDA diagnostic information for host: DESKTOP-G86FQHS
# 2022-04-09 13:05:59.617137: I tensorflow/stream_executor/cuda/cuda_diagnostics.cc:176] hostname: DESKTOP-G86FQHS
# 2022-04-09 13:05:59.617506: I tensorflow/core/platform/cpu_feature_guard.cc:142] Your CPU supports instructions that this TensorFlow binary was not compiled to use: AVX2
# Step 0: Loss 6.539424
#
# Step 100: Loss 3.5857005
#
# Step 200: Loss 1.4869714
#
# Step 300: Loss 0.89472735
#
# Step 400: Loss 0.62689465
#
# Step 500: Loss 0.56030446
#
# Step 600: Loss 0.9419728
#
# Step 700: Loss 0.6324588
#
# Step 800: Loss 0.55639696
#
# Step 900: Loss 0.38971096
#
# Training complete.
# 2022-04-09 13:06:46.718187: W tensorflow/stream_executor/platform/default/dso_loader.cc:55] Could not load dynamic library 'cudart64_100.dll'; dlerror: cudart64_100.dll not found
# 2022-04-09 13:06:46.718377: I tensorflow/stream_executor/cuda/cudart_stub.cc:29] Ignore above cudart dlerror if you do not have a GPU set up on your machine.
# WARNING:tensorflow:From C:\ProgramData\Anaconda3\envs\meshgraphnet\lib\site-packages\tensorflow_core\python\ops\resource_variable_ops.py:1630: calling BaseResourceVariable.__init__ (from tensorflow.python.ops.resource_variable_ops) with constraint is deprecated and will be removed in a future version.
# Instructions for updating:
# If using Keras pass *_constraint arguments to layers.
# WARNING:tensorflow:From C:\ProgramData\Anaconda3\envs\meshgraphnet\lib\site-packages\tensorflow_core\python\data\util\random_seed.py:58: where (from tensorflow.python.ops.array_ops) is deprecated and will be removed in a future version.
# Instructions for updating:
# Use tf.where in 2.0, which has the same broadcast rule as np.where
# WARNING:tensorflow:From C:\ProgramData\Anaconda3\envs\meshgraphnet\lib\site-packages\sonnet\python\modules\basic.py:127: calling TruncatedNormal.__init__ (from tensorflow.python.ops.init_ops) with dtype is deprecated and will be removed in a future version.
# Instructions for updating:
# Call initializer instance with the dtype argument instead of passing it to the constructor
# WARNING:tensorflow:From C:\ProgramData\Anaconda3\envs\meshgraphnet\lib\site-packages\sonnet\python\modules\basic.py:132: calling Zeros.__init__ (from tensorflow.python.ops.init_ops) with dtype is deprecated and will be removed in a future version.
# Instructions for updating:
# Call initializer instance with the dtype argument instead of passing it to the constructor
# WARNING:tensorflow:From C:\ProgramData\Anaconda3\envs\meshgraphnet\lib\site-packages\tensorflow_core\python\training\training_util.py:236: Variable.initialized_value (from tensorflow.python.ops.variables) is deprecated and will be removed in a future version.
# Instructions for updating:
# Use Variable.read_value. Variables in 2.X are initialized automatically both in eager and graph (inside tf.defun) contexts.
# 2022-04-09 13:06:53.655596: W tensorflow/stream_executor/platform/default/dso_loader.cc:55] Could not load dynamic library 'nvcuda.dll'; dlerror: nvcuda.dll not found
# 2022-04-09 13:06:53.655775: E tensorflow/stream_executor/cuda/cuda_driver.cc:318] failed call to cuInit: UNKNOWN ERROR (303)
# 2022-04-09 13:06:53.658740: I tensorflow/stream_executor/cuda/cuda_diagnostics.cc:169] retrieving CUDA diagnostic information for host: DESKTOP-G86FQHS
# 2022-04-09 13:06:53.659025: I tensorflow/stream_executor/cuda/cuda_diagnostics.cc:176] hostname: DESKTOP-G86FQHS
# 2022-04-09 13:06:53.659357: I tensorflow/core/platform/cpu_feature_guard.cc:142] Your CPU supports instructions that this TensorFlow binary was not compiled to use: AVX2
# Step 0: Loss 7.620092
#
# Step 100: Loss 2.2873604
#
# Step 200: Loss 0.3539547
#
# Step 300: Loss 0.082574844
#
# Step 400: Loss 0.18442845
#
# Step 500: Loss 0.061509497
#
# Step 600: Loss 0.05457352
#
# Step 700: Loss 0.059668627
#
# Step 800: Loss 0.036520526
#
# Step 900: Loss 0.030536264
#
# Training complete.
# 2022-04-09 13:07:41.202707: W tensorflow/stream_executor/platform/default/dso_loader.cc:55] Could not load dynamic library 'cudart64_100.dll'; dlerror: cudart64_100.dll not found
# 2022-04-09 13:07:41.202891: I tensorflow/stream_executor/cuda/cudart_stub.cc:29] Ignore above cudart dlerror if you do not have a GPU set up on your machine.
# WARNING:tensorflow:From C:\ProgramData\Anaconda3\envs\meshgraphnet\lib\site-packages\tensorflow_core\python\ops\resource_variable_ops.py:1630: calling BaseResourceVariable.__init__ (from tensorflow.python.ops.resource_variable_ops) with constraint is deprecated and will be removed in a future version.
# Instructions for updating:
# If using Keras pass *_constraint arguments to layers.
# WARNING:tensorflow:From C:\ProgramData\Anaconda3\envs\meshgraphnet\lib\site-packages\tensorflow_core\python\data\util\random_seed.py:58: where (from tensorflow.python.ops.array_ops) is deprecated and will be removed in a future version.
# Instructions for updating:
# Use tf.where in 2.0, which has the same broadcast rule as np.where
# WARNING:tensorflow:From C:\ProgramData\Anaconda3\envs\meshgraphnet\lib\site-packages\sonnet\python\modules\basic.py:127: calling TruncatedNormal.__init__ (from tensorflow.python.ops.init_ops) with dtype is deprecated and will be removed in a future version.
# Instructions for updating:
# Call initializer instance with the dtype argument instead of passing it to the constructor
# WARNING:tensorflow:From C:\ProgramData\Anaconda3\envs\meshgraphnet\lib\site-packages\sonnet\python\modules\basic.py:132: calling Zeros.__init__ (from tensorflow.python.ops.init_ops) with dtype is deprecated and will be removed in a future version.
# Instructions for updating:
# Call initializer instance with the dtype argument instead of passing it to the constructor
# WARNING:tensorflow:From C:\ProgramData\Anaconda3\envs\meshgraphnet\lib\site-packages\tensorflow_core\python\training\training_util.py:236: Variable.initialized_value (from tensorflow.python.ops.variables) is deprecated and will be removed in a future version.
# Instructions for updating:
# Use Variable.read_value. Variables in 2.X are initialized automatically both in eager and graph (inside tf.defun) contexts.
# 2022-04-09 13:07:48.324332: W tensorflow/stream_executor/platform/default/dso_loader.cc:55] Could not load dynamic library 'nvcuda.dll'; dlerror: nvcuda.dll not found
# 2022-04-09 13:07:48.324581: E tensorflow/stream_executor/cuda/cuda_driver.cc:318] failed call to cuInit: UNKNOWN ERROR (303)
# 2022-04-09 13:07:48.327608: I tensorflow/stream_executor/cuda/cuda_diagnostics.cc:169] retrieving CUDA diagnostic information for host: DESKTOP-G86FQHS
# 2022-04-09 13:07:48.327855: I tensorflow/stream_executor/cuda/cuda_diagnostics.cc:176] hostname: DESKTOP-G86FQHS
# 2022-04-09 13:07:48.328230: I tensorflow/core/platform/cpu_feature_guard.cc:142] Your CPU supports instructions that this TensorFlow binary was not compiled to use: AVX2
# Step 0: Loss 6.6086116
#
# Step 100: Loss 2.345947
#
# Step 200: Loss 0.16626206
#
# Step 300: Loss 0.09772377
#
# Step 400: Loss 0.11754146
#
# Step 500: Loss 0.09912624
#
# Step 600: Loss 0.098424904
#
# Step 700: Loss 0.053814977
#
# Step 800: Loss 0.045542847
#
# Step 900: Loss 0.08576887
#
# Training complete.
# 2022-04-09 13:08:37.078823: W tensorflow/stream_executor/platform/default/dso_loader.cc:55] Could not load dynamic library 'cudart64_100.dll'; dlerror: cudart64_100.dll not found
# 2022-04-09 13:08:37.079088: I tensorflow/stream_executor/cuda/cudart_stub.cc:29] Ignore above cudart dlerror if you do not have a GPU set up on your machine.
# WARNING:tensorflow:From C:\ProgramData\Anaconda3\envs\meshgraphnet\lib\site-packages\tensorflow_core\python\ops\resource_variable_ops.py:1630: calling BaseResourceVariable.__init__ (from tensorflow.python.ops.resource_variable_ops) with constraint is deprecated and will be removed in a future version.
# Instructions for updating:
# If using Keras pass *_constraint arguments to layers.
# WARNING:tensorflow:From c:\Temp\HybridML\meshgraphnets\normalization.py:73: where (from tensorflow.python.ops.array_ops) is deprecated and will be removed in a future version.
# Instructions for updating:
# Use tf.where in 2.0, which has the same broadcast rule as np.where
# WARNING:tensorflow:From C:\ProgramData\Anaconda3\envs\meshgraphnet\lib\site-packages\sonnet\python\modules\basic.py:127: calling TruncatedNormal.__init__ (from tensorflow.python.ops.init_ops) with dtype is deprecated and will be removed in a future version.
# Instructions for updating:
# Call initializer instance with the dtype argument instead of passing it to the constructor
# WARNING:tensorflow:From C:\ProgramData\Anaconda3\envs\meshgraphnet\lib\site-packages\sonnet\python\modules\basic.py:132: calling Zeros.__init__ (from tensorflow.python.ops.init_ops) with dtype is deprecated and will be removed in a future version.
# Instructions for updating:
# Call initializer instance with the dtype argument instead of passing it to the constructor
# WARNING:tensorflow:From C:\ProgramData\Anaconda3\envs\meshgraphnet\lib\site-packages\tensorflow_core\python\training\training_util.py:236: Variable.initialized_value (from tensorflow.python.ops.variables) is deprecated and will be removed in a future version.
# Instructions for updating:
# Use Variable.read_value. Variables in 2.X are initialized automatically both in eager and graph (inside tf.defun) contexts.
# 2022-04-09 13:08:42.193699: W tensorflow/stream_executor/platform/default/dso_loader.cc:55] Could not load dynamic library 'nvcuda.dll'; dlerror: nvcuda.dll not found
# 2022-04-09 13:08:42.193850: E tensorflow/stream_executor/cuda/cuda_driver.cc:318] failed call to cuInit: UNKNOWN ERROR (303)
# 2022-04-09 13:08:42.196683: I tensorflow/stream_executor/cuda/cuda_diagnostics.cc:169] retrieving CUDA diagnostic information for host: DESKTOP-G86FQHS
# 2022-04-09 13:08:42.196970: I tensorflow/stream_executor/cuda/cuda_diagnostics.cc:176] hostname: DESKTOP-G86FQHS
# 2022-04-09 13:08:42.197317: I tensorflow/core/platform/cpu_feature_guard.cc:142] Your CPU supports instructions that this TensorFlow binary was not compiled to use: AVX2
# WARNING:tensorflow:From C:\ProgramData\Anaconda3\envs\meshgraphnet\lib\site-packages\tensorflow_core\python\training\saver.py:1069: get_checkpoint_mtimes (from tensorflow.python.training.checkpoint_management) is deprecated and will be removed in a future version.
# Instructions for updating:
# Use standard file utilities to get mtimes.
# WARNING:tensorflow:It seems that global step (tf.train.get_global_step) has not been increased. Current value (could be stable): 1000 vs previous value: 1000. You could increase the global step by passing tf.train.get_global_step() to Optimizer.apply_gradients or Optimizer.minimize.
# WARNING:tensorflow:It seems that global step (tf.train.get_global_step) has not been increased. Current value (could be stable): 1000 vs previous value: 1000. You could increase the global step by passing tf.train.get_global_step() to Optimizer.apply_gradients or Optimizer.minimize.
# WARNING:tensorflow:It seems that global step (tf.train.get_global_step) has not been increased. Current value (could be stable): 1000 vs previous value: 1000. You could increase the global step by passing tf.train.get_global_step() to Optimizer.apply_gradients or Optimizer.minimize.
# Error List: [0.00015452193, 3.0595755e-05, 5.6554218e-05, 5.795873e-05]
# 2022-04-09 13:08:43.717706: W tensorflow/stream_executor/platform/default/dso_loader.cc:55] Could not load dynamic library 'cudart64_100.dll'; dlerror: cudart64_100.dll not found
# 2022-04-09 13:08:43.717936: I tensorflow/stream_executor/cuda/cudart_stub.cc:29] Ignore above cudart dlerror if you do not have a GPU set up on your machine.
# WARNING:tensorflow:From C:\ProgramData\Anaconda3\envs\meshgraphnet\lib\site-packages\tensorflow_core\python\ops\resource_variable_ops.py:1630: calling BaseResourceVariable.__init__ (from tensorflow.python.ops.resource_variable_ops) with constraint is deprecated and will be removed in a future version.
# Instructions for updating:
# If using Keras pass *_constraint arguments to layers.
# WARNING:tensorflow:From c:\Temp\HybridML\meshgraphnets\normalization.py:73: where (from tensorflow.python.ops.array_ops) is deprecated and will be removed in a future version.
# Instructions for updating:
# Use tf.where in 2.0, which has the same broadcast rule as np.where
# WARNING:tensorflow:From C:\ProgramData\Anaconda3\envs\meshgraphnet\lib\site-packages\sonnet\python\modules\basic.py:127: calling TruncatedNormal.__init__ (from tensorflow.python.ops.init_ops) with dtype is deprecated and will be removed in a future version.
# Instructions for updating:
# Call initializer instance with the dtype argument instead of passing it to the constructor
# WARNING:tensorflow:From C:\ProgramData\Anaconda3\envs\meshgraphnet\lib\site-packages\sonnet\python\modules\basic.py:132: calling Zeros.__init__ (from tensorflow.python.ops.init_ops) with dtype is deprecated and will be removed in a future version.
# Instructions for updating:
# Call initializer instance with the dtype argument instead of passing it to the constructor
# WARNING:tensorflow:From C:\ProgramData\Anaconda3\envs\meshgraphnet\lib\site-packages\tensorflow_core\python\training\training_util.py:236: Variable.initialized_value (from tensorflow.python.ops.variables) is deprecated and will be removed in a future version.
# Instructions for updating:
# Use Variable.read_value. Variables in 2.X are initialized automatically both in eager and graph (inside tf.defun) contexts.
# 2022-04-09 13:08:48.748769: W tensorflow/stream_executor/platform/default/dso_loader.cc:55] Could not load dynamic library 'nvcuda.dll'; dlerror: nvcuda.dll not found
# 2022-04-09 13:08:48.748976: E tensorflow/stream_executor/cuda/cuda_driver.cc:318] failed call to cuInit: UNKNOWN ERROR (303)
# 2022-04-09 13:08:48.752857: I tensorflow/stream_executor/cuda/cuda_diagnostics.cc:169] retrieving CUDA diagnostic information for host: DESKTOP-G86FQHS
# 2022-04-09 13:08:48.753076: I tensorflow/stream_executor/cuda/cuda_diagnostics.cc:176] hostname: DESKTOP-G86FQHS
# 2022-04-09 13:08:48.753376: I tensorflow/core/platform/cpu_feature_guard.cc:142] Your CPU supports instructions that this TensorFlow binary was not compiled to use: AVX2
# WARNING:tensorflow:From C:\ProgramData\Anaconda3\envs\meshgraphnet\lib\site-packages\tensorflow_core\python\training\saver.py:1069: get_checkpoint_mtimes (from tensorflow.python.training.checkpoint_management) is deprecated and will be removed in a future version.
# Instructions for updating:
# Use standard file utilities to get mtimes.
# WARNING:tensorflow:It seems that global step (tf.train.get_global_step) has not been increased. Current value (could be stable): 1000 vs previous value: 1000. You could increase the global step by passing tf.train.get_global_step() to Optimizer.apply_gradients or Optimizer.minimize.
# WARNING:tensorflow:It seems that global step (tf.train.get_global_step) has not been increased. Current value (could be stable): 1000 vs previous value: 1000. You could increase the global step by passing tf.train.get_global_step() to Optimizer.apply_gradients or Optimizer.minimize.
# WARNING:tensorflow:It seems that global step (tf.train.get_global_step) has not been increased. Current value (could be stable): 1000 vs previous value: 1000. You could increase the global step by passing tf.train.get_global_step() to Optimizer.apply_gradients or Optimizer.minimize.
# Error List: [1.1781683e-06, 1.2455235e-06, 1.6111279e-06, 7.022543e-07]
# 2022-04-09 13:08:50.308305: W tensorflow/stream_executor/platform/default/dso_loader.cc:55] Could not load dynamic library 'cudart64_100.dll'; dlerror: cudart64_100.dll not found
# 2022-04-09 13:08:50.308500: I tensorflow/stream_executor/cuda/cudart_stub.cc:29] Ignore above cudart dlerror if you do not have a GPU set up on your machine.
# WARNING:tensorflow:From C:\ProgramData\Anaconda3\envs\meshgraphnet\lib\site-packages\tensorflow_core\python\ops\resource_variable_ops.py:1630: calling BaseResourceVariable.__init__ (from tensorflow.python.ops.resource_variable_ops) with constraint is deprecated and will be removed in a future version.
# Instructions for updating:
# If using Keras pass *_constraint arguments to layers.
# WARNING:tensorflow:From c:\Temp\HybridML\meshgraphnets\normalization.py:73: where (from tensorflow.python.ops.array_ops) is deprecated and will be removed in a future version.
# Instructions for updating:
# Use tf.where in 2.0, which has the same broadcast rule as np.where
# WARNING:tensorflow:From C:\ProgramData\Anaconda3\envs\meshgraphnet\lib\site-packages\sonnet\python\modules\basic.py:127: calling TruncatedNormal.__init__ (from tensorflow.python.ops.init_ops) with dtype is deprecated and will be removed in a future version.
# Instructions for updating:
# Call initializer instance with the dtype argument instead of passing it to the constructor
# WARNING:tensorflow:From C:\ProgramData\Anaconda3\envs\meshgraphnet\lib\site-packages\sonnet\python\modules\basic.py:132: calling Zeros.__init__ (from tensorflow.python.ops.init_ops) with dtype is deprecated and will be removed in a future version.
# Instructions for updating:
# Call initializer instance with the dtype argument instead of passing it to the constructor
# WARNING:tensorflow:From C:\ProgramData\Anaconda3\envs\meshgraphnet\lib\site-packages\tensorflow_core\python\training\training_util.py:236: Variable.initialized_value (from tensorflow.python.ops.variables) is deprecated and will be removed in a future version.
# Instructions for updating:
# Use Variable.read_value. Variables in 2.X are initialized automatically both in eager and graph (inside tf.defun) contexts.
# 2022-04-09 13:08:55.111032: W tensorflow/stream_executor/platform/default/dso_loader.cc:55] Could not load dynamic library 'nvcuda.dll'; dlerror: nvcuda.dll not found
# 2022-04-09 13:08:55.111214: E tensorflow/stream_executor/cuda/cuda_driver.cc:318] failed call to cuInit: UNKNOWN ERROR (303)
# 2022-04-09 13:08:55.114009: I tensorflow/stream_executor/cuda/cuda_diagnostics.cc:169] retrieving CUDA diagnostic information for host: DESKTOP-G86FQHS
# 2022-04-09 13:08:55.114284: I tensorflow/stream_executor/cuda/cuda_diagnostics.cc:176] hostname: DESKTOP-G86FQHS
# 2022-04-09 13:08:55.114686: I tensorflow/core/platform/cpu_feature_guard.cc:142] Your CPU supports instructions that this TensorFlow binary was not compiled to use: AVX2
# WARNING:tensorflow:From C:\ProgramData\Anaconda3\envs\meshgraphnet\lib\site-packages\tensorflow_core\python\training\saver.py:1069: get_checkpoint_mtimes (from tensorflow.python.training.checkpoint_management) is deprecated and will be removed in a future version.
# Instructions for updating:
# Use standard file utilities to get mtimes.
# WARNING:tensorflow:It seems that global step (tf.train.get_global_step) has not been increased. Current value (could be stable): 1000 vs previous value: 1000. You could increase the global step by passing tf.train.get_global_step() to Optimizer.apply_gradients or Optimizer.minimize.
# WARNING:tensorflow:It seems that global step (tf.train.get_global_step) has not been increased. Current value (could be stable): 1000 vs previous value: 1000. You could increase the global step by passing tf.train.get_global_step() to Optimizer.apply_gradients or Optimizer.minimize.
# WARNING:tensorflow:It seems that global step (tf.train.get_global_step) has not been increased. Current value (could be stable): 1000 vs previous value: 1000. You could increase the global step by passing tf.train.get_global_step() to Optimizer.apply_gradients or Optimizer.minimize.
# Error List: [1.1645087e-06, 1.2536693e-06, 2.1300186e-06, 7.7030495e-07]
# 2022-04-09 13:08:56.622899: W tensorflow/stream_executor/platform/default/dso_loader.cc:55] Could not load dynamic library 'cudart64_100.dll'; dlerror: cudart64_100.dll not found
# 2022-04-09 13:08:56.623093: I tensorflow/stream_executor/cuda/cudart_stub.cc:29] Ignore above cudart dlerror if you do not have a GPU set up on your machine.
# WARNING:tensorflow:From C:\ProgramData\Anaconda3\envs\meshgraphnet\lib\site-packages\tensorflow_core\python\ops\resource_variable_ops.py:1630: calling BaseResourceVariable.__init__ (from tensorflow.python.ops.resource_variable_ops) with constraint is deprecated and will be removed in a future version.
# Instructions for updating:
# If using Keras pass *_constraint arguments to layers.
# WARNING:tensorflow:From c:\Temp\HybridML\meshgraphnets\normalization.py:73: where (from tensorflow.python.ops.array_ops) is deprecated and will be removed in a future version.
# Instructions for updating:
# Use tf.where in 2.0, which has the same broadcast rule as np.where
# WARNING:tensorflow:From C:\ProgramData\Anaconda3\envs\meshgraphnet\lib\site-packages\sonnet\python\modules\basic.py:127: calling TruncatedNormal.__init__ (from tensorflow.python.ops.init_ops) with dtype is deprecated and will be removed in a future version.
# Instructions for updating:
# Call initializer instance with the dtype argument instead of passing it to the constructor
# WARNING:tensorflow:From C:\ProgramData\Anaconda3\envs\meshgraphnet\lib\site-packages\sonnet\python\modules\basic.py:132: calling Zeros.__init__ (from tensorflow.python.ops.init_ops) with dtype is deprecated and will be removed in a future version.
# Instructions for updating:
# Call initializer instance with the dtype argument instead of passing it to the constructor
# WARNING:tensorflow:From C:\ProgramData\Anaconda3\envs\meshgraphnet\lib\site-packages\tensorflow_core\python\training\training_util.py:236: Variable.initialized_value (from tensorflow.python.ops.variables) is deprecated and will be removed in a future version.
# Instructions for updating:
# Use Variable.read_value. Variables in 2.X are initialized automatically both in eager and graph (inside tf.defun) contexts.
# 2022-04-09 13:09:01.332379: W tensorflow/stream_executor/platform/default/dso_loader.cc:55] Could not load dynamic library 'nvcuda.dll'; dlerror: nvcuda.dll not found
# 2022-04-09 13:09:01.332510: E tensorflow/stream_executor/cuda/cuda_driver.cc:318] failed call to cuInit: UNKNOWN ERROR (303)
# 2022-04-09 13:09:01.335408: I tensorflow/stream_executor/cuda/cuda_diagnostics.cc:169] retrieving CUDA diagnostic information for host: DESKTOP-G86FQHS
# 2022-04-09 13:09:01.335615: I tensorflow/stream_executor/cuda/cuda_diagnostics.cc:176] hostname: DESKTOP-G86FQHS
# 2022-04-09 13:09:01.335966: I tensorflow/core/platform/cpu_feature_guard.cc:142] Your CPU supports instructions that this TensorFlow binary was not compiled to use: AVX2
# WARNING:tensorflow:From C:\ProgramData\Anaconda3\envs\meshgraphnet\lib\site-packages\tensorflow_core\python\training\saver.py:1069: get_checkpoint_mtimes (from tensorflow.python.training.checkpoint_management) is deprecated and will be removed in a future version.
# Instructions for updating:
# Use standard file utilities to get mtimes.
# WARNING:tensorflow:It seems that global step (tf.train.get_global_step) has not been increased. Current value (could be stable): 1000 vs previous value: 1000. You could increase the global step by passing tf.train.get_global_step() to Optimizer.apply_gradients or Optimizer.minimize.
# WARNING:tensorflow:It seems that global step (tf.train.get_global_step) has not been increased. Current value (could be stable): 1000 vs previous value: 1000. You could increase the global step by passing tf.train.get_global_step() to Optimizer.apply_gradients or Optimizer.minimize.
# WARNING:tensorflow:It seems that global step (tf.train.get_global_step) has not been increased. Current value (could be stable): 1000 vs previous value: 1000. You could increase the global step by passing tf.train.get_global_step() to Optimizer.apply_gradients or Optimizer.minimize.
# WARNING:tensorflow:It seems that global step (tf.train.get_global_step) has not been increased. Current value (could be stable): 1000 vs previous value: 1000. You could increase the global step by passing tf.train.get_global_step() to Optimizer.apply_gradients or Optimizer.minimize.
# WARNING:tensorflow:It seems that global step (tf.train.get_global_step) has not been increased. Current value (could be stable): 1000 vs previous value: 1000. You could increase the global step by passing tf.train.get_global_step() to Optimizer.apply_gradients or Optimizer.minimize.
# Error List: [0.00025642355, 0.0012280479, 0.00059244415, 0.00035771032, 0.00021255064, 0.00032417796, 0.0023496451, 0.0015226409, 0.00044058234, 0.001976773]
# 2022-04-09 13:09:02.941609: W tensorflow/stream_executor/platform/default/dso_loader.cc:55] Could not load dynamic library 'cudart64_100.dll'; dlerror: cudart64_100.dll not found
# 2022-04-09 13:09:02.941764: I tensorflow/stream_executor/cuda/cudart_stub.cc:29] Ignore above cudart dlerror if you do not have a GPU set up on your machine.
# WARNING:tensorflow:From C:\ProgramData\Anaconda3\envs\meshgraphnet\lib\site-packages\tensorflow_core\python\ops\resource_variable_ops.py:1630: calling BaseResourceVariable.__init__ (from tensorflow.python.ops.resource_variable_ops) with constraint is deprecated and will be removed in a future version.
# Instructions for updating:
# If using Keras pass *_constraint arguments to layers.
# WARNING:tensorflow:From c:\Temp\HybridML\meshgraphnets\normalization.py:73: where (from tensorflow.python.ops.array_ops) is deprecated and will be removed in a future version.
# Instructions for updating:
# Use tf.where in 2.0, which has the same broadcast rule as np.where
# WARNING:tensorflow:From C:\ProgramData\Anaconda3\envs\meshgraphnet\lib\site-packages\sonnet\python\modules\basic.py:127: calling TruncatedNormal.__init__ (from tensorflow.python.ops.init_ops) with dtype is deprecated and will be removed in a future version.
# Instructions for updating:
# Call initializer instance with the dtype argument instead of passing it to the constructor
# WARNING:tensorflow:From C:\ProgramData\Anaconda3\envs\meshgraphnet\lib\site-packages\sonnet\python\modules\basic.py:132: calling Zeros.__init__ (from tensorflow.python.ops.init_ops) with dtype is deprecated and will be removed in a future version.
# Instructions for updating:
# Call initializer instance with the dtype argument instead of passing it to the constructor
# WARNING:tensorflow:From C:\ProgramData\Anaconda3\envs\meshgraphnet\lib\site-packages\tensorflow_core\python\training\training_util.py:236: Variable.initialized_value (from tensorflow.python.ops.variables) is deprecated and will be removed in a future version.
# Instructions for updating:
# Use Variable.read_value. Variables in 2.X are initialized automatically both in eager and graph (inside tf.defun) contexts.
# 2022-04-09 13:09:07.911611: W tensorflow/stream_executor/platform/default/dso_loader.cc:55] Could not load dynamic library 'nvcuda.dll'; dlerror: nvcuda.dll not found
# 2022-04-09 13:09:07.911780: E tensorflow/stream_executor/cuda/cuda_driver.cc:318] failed call to cuInit: UNKNOWN ERROR (303)
# 2022-04-09 13:09:07.915535: I tensorflow/stream_executor/cuda/cuda_diagnostics.cc:169] retrieving CUDA diagnostic information for host: DESKTOP-G86FQHS
# 2022-04-09 13:09:07.915731: I tensorflow/stream_executor/cuda/cuda_diagnostics.cc:176] hostname: DESKTOP-G86FQHS
# 2022-04-09 13:09:07.916091: I tensorflow/core/platform/cpu_feature_guard.cc:142] Your CPU supports instructions that this TensorFlow binary was not compiled to use: AVX2
# WARNING:tensorflow:From C:\ProgramData\Anaconda3\envs\meshgraphnet\lib\site-packages\tensorflow_core\python\training\saver.py:1069: get_checkpoint_mtimes (from tensorflow.python.training.checkpoint_management) is deprecated and will be removed in a future version.
# Instructions for updating:
# Use standard file utilities to get mtimes.
# WARNING:tensorflow:It seems that global step (tf.train.get_global_step) has not been increased. Current value (could be stable): 1000 vs previous value: 1000. You could increase the global step by passing tf.train.get_global_step() to Optimizer.apply_gradients or Optimizer.minimize.
# WARNING:tensorflow:It seems that global step (tf.train.get_global_step) has not been increased. Current value (could be stable): 1000 vs previous value: 1000. You could increase the global step by passing tf.train.get_global_step() to Optimizer.apply_gradients or Optimizer.minimize.
# WARNING:tensorflow:It seems that global step (tf.train.get_global_step) has not been increased. Current value (could be stable): 1000 vs previous value: 1000. You could increase the global step by passing tf.train.get_global_step() to Optimizer.apply_gradients or Optimizer.minimize.
# WARNING:tensorflow:It seems that global step (tf.train.get_global_step) has not been increased. Current value (could be stable): 1000 vs previous value: 1000. You could increase the global step by passing tf.train.get_global_step() to Optimizer.apply_gradients or Optimizer.minimize.
# WARNING:tensorflow:It seems that global step (tf.train.get_global_step) has not been increased. Current value (could be stable): 1000 vs previous value: 1000. You could increase the global step by passing tf.train.get_global_step() to Optimizer.apply_gradients or Optimizer.minimize.
# Error List: [6.477907e-05, 0.00018918682, 0.0006720538, 0.0001303414, 0.0005798639, 0.0004319352, 0.000356072, 0.00020964682, 4.9513546e-05, 0.00011648216]
# 2022-04-09 13:09:09.493004: W tensorflow/stream_executor/platform/default/dso_loader.cc:55] Could not load dynamic library 'cudart64_100.dll'; dlerror: cudart64_100.dll not found
# 2022-04-09 13:09:09.493156: I tensorflow/stream_executor/cuda/cudart_stub.cc:29] Ignore above cudart dlerror if you do not have a GPU set up on your machine.
# WARNING:tensorflow:From C:\ProgramData\Anaconda3\envs\meshgraphnet\lib\site-packages\tensorflow_core\python\ops\resource_variable_ops.py:1630: calling BaseResourceVariable.__init__ (from tensorflow.python.ops.resource_variable_ops) with constraint is deprecated and will be removed in a future version.
# Instructions for updating:
# If using Keras pass *_constraint arguments to layers.
# WARNING:tensorflow:From c:\Temp\HybridML\meshgraphnets\normalization.py:73: where (from tensorflow.python.ops.array_ops) is deprecated and will be removed in a future version.
# Instructions for updating:
# Use tf.where in 2.0, which has the same broadcast rule as np.where
# WARNING:tensorflow:From C:\ProgramData\Anaconda3\envs\meshgraphnet\lib\site-packages\sonnet\python\modules\basic.py:127: calling TruncatedNormal.__init__ (from tensorflow.python.ops.init_ops) with dtype is deprecated and will be removed in a future version.
# Instructions for updating:
# Call initializer instance with the dtype argument instead of passing it to the constructor
# WARNING:tensorflow:From C:\ProgramData\Anaconda3\envs\meshgraphnet\lib\site-packages\sonnet\python\modules\basic.py:132: calling Zeros.__init__ (from tensorflow.python.ops.init_ops) with dtype is deprecated and will be removed in a future version.
# Instructions for updating:
# Call initializer instance with the dtype argument instead of passing it to the constructor
# WARNING:tensorflow:From C:\ProgramData\Anaconda3\envs\meshgraphnet\lib\site-packages\tensorflow_core\python\training\training_util.py:236: Variable.initialized_value (from tensorflow.python.ops.variables) is deprecated and will be removed in a future version.
# Instructions for updating:
# Use Variable.read_value. Variables in 2.X are initialized automatically both in eager and graph (inside tf.defun) contexts.
# 2022-04-09 13:09:14.547528: W tensorflow/stream_executor/platform/default/dso_loader.cc:55] Could not load dynamic library 'nvcuda.dll'; dlerror: nvcuda.dll not found
# 2022-04-09 13:09:14.547766: E tensorflow/stream_executor/cuda/cuda_driver.cc:318] failed call to cuInit: UNKNOWN ERROR (303)
# 2022-04-09 13:09:14.551304: I tensorflow/stream_executor/cuda/cuda_diagnostics.cc:169] retrieving CUDA diagnostic information for host: DESKTOP-G86FQHS
# 2022-04-09 13:09:14.551555: I tensorflow/stream_executor/cuda/cuda_diagnostics.cc:176] hostname: DESKTOP-G86FQHS
# 2022-04-09 13:09:14.551929: I tensorflow/core/platform/cpu_feature_guard.cc:142] Your CPU supports instructions that this TensorFlow binary was not compiled to use: AVX2
# WARNING:tensorflow:From C:\ProgramData\Anaconda3\envs\meshgraphnet\lib\site-packages\tensorflow_core\python\training\saver.py:1069: get_checkpoint_mtimes (from tensorflow.python.training.checkpoint_management) is deprecated and will be removed in a future version.
# Instructions for updating:
# Use standard file utilities to get mtimes.
# WARNING:tensorflow:It seems that global step (tf.train.get_global_step) has not been increased. Current value (could be stable): 1000 vs previous value: 1000. You could increase the global step by passing tf.train.get_global_step() to Optimizer.apply_gradients or Optimizer.minimize.
# WARNING:tensorflow:It seems that global step (tf.train.get_global_step) has not been increased. Current value (could be stable): 1000 vs previous value: 1000. You could increase the global step by passing tf.train.get_global_step() to Optimizer.apply_gradients or Optimizer.minimize.
# WARNING:tensorflow:It seems that global step (tf.train.get_global_step) has not been increased. Current value (could be stable): 1000 vs previous value: 1000. You could increase the global step by passing tf.train.get_global_step() to Optimizer.apply_gradients or Optimizer.minimize.
# WARNING:tensorflow:It seems that global step (tf.train.get_global_step) has not been increased. Current value (could be stable): 1000 vs previous value: 1000. You could increase the global step by passing tf.train.get_global_step() to Optimizer.apply_gradients or Optimizer.minimize.
# WARNING:tensorflow:It seems that global step (tf.train.get_global_step) has not been increased. Current value (could be stable): 1000 vs previous value: 1000. You could increase the global step by passing tf.train.get_global_step() to Optimizer.apply_gradients or Optimizer.minimize.
# Error List: [0.00015339782, 0.00043416864, 0.00026998483, 2.7587294e-05, 0.0002811935, 0.0001850435, 0.00097404525, 0.0006216045, 0.00019952608, 0.00014985874]
# 2022-04-09 13:09:16.142677: W tensorflow/stream_executor/platform/default/dso_loader.cc:55] Could not load dynamic library 'cudart64_100.dll'; dlerror: cudart64_100.dll not found
# 2022-04-09 13:09:16.142813: I tensorflow/stream_executor/cuda/cudart_stub.cc:29] Ignore above cudart dlerror if you do not have a GPU set up on your machine.
# WARNING:tensorflow:From C:\ProgramData\Anaconda3\envs\meshgraphnet\lib\site-packages\tensorflow_core\python\ops\resource_variable_ops.py:1630: calling BaseResourceVariable.__init__ (from tensorflow.python.ops.resource_variable_ops) with constraint is deprecated and will be removed in a future version.
# Instructions for updating:
# If using Keras pass *_constraint arguments to layers.
# WARNING:tensorflow:From c:\Temp\HybridML\meshgraphnets\normalization.py:73: where (from tensorflow.python.ops.array_ops) is deprecated and will be removed in a future version.
# Instructions for updating:
# Use tf.where in 2.0, which has the same broadcast rule as np.where
# WARNING:tensorflow:From C:\ProgramData\Anaconda3\envs\meshgraphnet\lib\site-packages\sonnet\python\modules\basic.py:127: calling TruncatedNormal.__init__ (from tensorflow.python.ops.init_ops) with dtype is deprecated and will be removed in a future version.
# Instructions for updating:
# Call initializer instance with the dtype argument instead of passing it to the constructor
# WARNING:tensorflow:From C:\ProgramData\Anaconda3\envs\meshgraphnet\lib\site-packages\sonnet\python\modules\basic.py:132: calling Zeros.__init__ (from tensorflow.python.ops.init_ops) with dtype is deprecated and will be removed in a future version.
# Instructions for updating:
# Call initializer instance with the dtype argument instead of passing it to the constructor
# WARNING:tensorflow:From C:\ProgramData\Anaconda3\envs\meshgraphnet\lib\site-packages\tensorflow_core\python\training\training_util.py:236: Variable.initialized_value (from tensorflow.python.ops.variables) is deprecated and will be removed in a future version.
# Instructions for updating:
# Use Variable.read_value. Variables in 2.X are initialized automatically both in eager and graph (inside tf.defun) contexts.
# 2022-04-09 13:09:20.932550: W tensorflow/stream_executor/platform/default/dso_loader.cc:55] Could not load dynamic library 'nvcuda.dll'; dlerror: nvcuda.dll not found
# 2022-04-09 13:09:20.932743: E tensorflow/stream_executor/cuda/cuda_driver.cc:318] failed call to cuInit: UNKNOWN ERROR (303)
# 2022-04-09 13:09:20.936254: I tensorflow/stream_executor/cuda/cuda_diagnostics.cc:169] retrieving CUDA diagnostic information for host: DESKTOP-G86FQHS
# 2022-04-09 13:09:20.936599: I tensorflow/stream_executor/cuda/cuda_diagnostics.cc:176] hostname: DESKTOP-G86FQHS
# 2022-04-09 13:09:20.937015: I tensorflow/core/platform/cpu_feature_guard.cc:142] Your CPU supports instructions that this TensorFlow binary was not compiled to use: AVX2
# WARNING:tensorflow:From C:\ProgramData\Anaconda3\envs\meshgraphnet\lib\site-packages\tensorflow_core\python\training\saver.py:1069: get_checkpoint_mtimes (from tensorflow.python.training.checkpoint_management) is deprecated and will be removed in a future version.
# Instructions for updating:
# Use standard file utilities to get mtimes.
# WARNING:tensorflow:It seems that global step (tf.train.get_global_step) has not been increased. Current value (could be stable): 1000 vs previous value: 1000. You could increase the global step by passing tf.train.get_global_step() to Optimizer.apply_gradients or Optimizer.minimize.
# WARNING:tensorflow:It seems that global step (tf.train.get_global_step) has not been increased. Current value (could be stable): 1000 vs previous value: 1000. You could increase the global step by passing tf.train.get_global_step() to Optimizer.apply_gradients or Optimizer.minimize.
# WARNING:tensorflow:It seems that global step (tf.train.get_global_step) has not been increased. Current value (could be stable): 1000 vs previous value: 1000. You could increase the global step by passing tf.train.get_global_step() to Optimizer.apply_gradients or Optimizer.minimize.
# WARNING:tensorflow:It seems that global step (tf.train.get_global_step) has not been increased. Current value (could be stable): 1000 vs previous value: 1000. You could increase the global step by passing tf.train.get_global_step() to Optimizer.apply_gradients or Optimizer.minimize.
# WARNING:tensorflow:It seems that global step (tf.train.get_global_step) has not been increased. Current value (could be stable): 1000 vs previous value: 1000. You could increase the global step by passing tf.train.get_global_step() to Optimizer.apply_gradients or Optimizer.minimize.
# Error List: [0.0014809011, 0.0015667516, 0.0009350898, 0.00034480623, 0.00074819714, 0.0009736492, 0.00044171637, 0.0010269395, 0.000675738, 0.00053667545]
# 2022-04-09 13:09:22.478047: W tensorflow/stream_executor/platform/default/dso_loader.cc:55] Could not load dynamic library 'cudart64_100.dll'; dlerror: cudart64_100.dll not found
# 2022-04-09 13:09:22.478295: I tensorflow/stream_executor/cuda/cudart_stub.cc:29] Ignore above cudart dlerror if you do not have a GPU set up on your machine.
# WARNING:tensorflow:From C:\ProgramData\Anaconda3\envs\meshgraphnet\lib\site-packages\tensorflow_core\python\ops\resource_variable_ops.py:1630: calling BaseResourceVariable.__init__ (from tensorflow.python.ops.resource_variable_ops) with constraint is deprecated and will be removed in a future version.
# Instructions for updating:
# If using Keras pass *_constraint arguments to layers.
# WARNING:tensorflow:From c:\Temp\HybridML\meshgraphnets\normalization.py:73: where (from tensorflow.python.ops.array_ops) is deprecated and will be removed in a future version.
# Instructions for updating:
# Use tf.where in 2.0, which has the same broadcast rule as np.where
# WARNING:tensorflow:From C:\ProgramData\Anaconda3\envs\meshgraphnet\lib\site-packages\sonnet\python\modules\basic.py:127: calling TruncatedNormal.__init__ (from tensorflow.python.ops.init_ops) with dtype is deprecated and will be removed in a future version.
# Instructions for updating:
# Call initializer instance with the dtype argument instead of passing it to the constructor
# WARNING:tensorflow:From C:\ProgramData\Anaconda3\envs\meshgraphnet\lib\site-packages\sonnet\python\modules\basic.py:132: calling Zeros.__init__ (from tensorflow.python.ops.init_ops) with dtype is deprecated and will be removed in a future version.
# Instructions for updating:
# Call initializer instance with the dtype argument instead of passing it to the constructor
# WARNING:tensorflow:From C:\ProgramData\Anaconda3\envs\meshgraphnet\lib\site-packages\tensorflow_core\python\training\training_util.py:236: Variable.initialized_value (from tensorflow.python.ops.variables) is deprecated and will be removed in a future version.
# Instructions for updating:
# Use Variable.read_value. Variables in 2.X are initialized automatically both in eager and graph (inside tf.defun) contexts.
# 2022-04-09 13:09:27.461353: W tensorflow/stream_executor/platform/default/dso_loader.cc:55] Could not load dynamic library 'nvcuda.dll'; dlerror: nvcuda.dll not found
# 2022-04-09 13:09:27.461531: E tensorflow/stream_executor/cuda/cuda_driver.cc:318] failed call to cuInit: UNKNOWN ERROR (303)
# 2022-04-09 13:09:27.464243: I tensorflow/stream_executor/cuda/cuda_diagnostics.cc:169] retrieving CUDA diagnostic information for host: DESKTOP-G86FQHS
# 2022-04-09 13:09:27.464502: I tensorflow/stream_executor/cuda/cuda_diagnostics.cc:176] hostname: DESKTOP-G86FQHS
# 2022-04-09 13:09:27.464855: I tensorflow/core/platform/cpu_feature_guard.cc:142] Your CPU supports instructions that this TensorFlow binary was not compiled to use: AVX2
# WARNING:tensorflow:From C:\ProgramData\Anaconda3\envs\meshgraphnet\lib\site-packages\tensorflow_core\python\training\saver.py:1069: get_checkpoint_mtimes (from tensorflow.python.training.checkpoint_management) is deprecated and will be removed in a future version.
# Instructions for updating:
# Use standard file utilities to get mtimes.
# WARNING:tensorflow:It seems that global step (tf.train.get_global_step) has not been increased. Current value (could be stable): 1000 vs previous value: 1000. You could increase the global step by passing tf.train.get_global_step() to Optimizer.apply_gradients or Optimizer.minimize.
# WARNING:tensorflow:It seems that global step (tf.train.get_global_step) has not been increased. Current value (could be stable): 1000 vs previous value: 1000. You could increase the global step by passing tf.train.get_global_step() to Optimizer.apply_gradients or Optimizer.minimize.
# WARNING:tensorflow:It seems that global step (tf.train.get_global_step) has not been increased. Current value (could be stable): 1000 vs previous value: 1000. You could increase the global step by passing tf.train.get_global_step() to Optimizer.apply_gradients or Optimizer.minimize.
# WARNING:tensorflow:It seems that global step (tf.train.get_global_step) has not been increased. Current value (could be stable): 1000 vs previous value: 1000. You could increase the global step by passing tf.train.get_global_step() to Optimizer.apply_gradients or Optimizer.minimize.
# WARNING:tensorflow:It seems that global step (tf.train.get_global_step) has not been increased. Current value (could be stable): 1000 vs previous value: 1000. You could increase the global step by passing tf.train.get_global_step() to Optimizer.apply_gradients or Optimizer.minimize.
# Error List: [0.0004872852, 0.00018561176, 8.532176e-05, 0.00017436301, 0.00012147548, 0.00012456262, 0.00023729191, 0.00065110525, 0.00032059022, 0.00015099441]
# 2022-04-09 13:09:29.001992: W tensorflow/stream_executor/platform/default/dso_loader.cc:55] Could not load dynamic library 'cudart64_100.dll'; dlerror: cudart64_100.dll not found
# 2022-04-09 13:09:29.002187: I tensorflow/stream_executor/cuda/cudart_stub.cc:29] Ignore above cudart dlerror if you do not have a GPU set up on your machine.
# WARNING:tensorflow:From C:\ProgramData\Anaconda3\envs\meshgraphnet\lib\site-packages\tensorflow_core\python\ops\resource_variable_ops.py:1630: calling BaseResourceVariable.__init__ (from tensorflow.python.ops.resource_variable_ops) with constraint is deprecated and will be removed in a future version.
# Instructions for updating:
# If using Keras pass *_constraint arguments to layers.
# WARNING:tensorflow:From c:\Temp\HybridML\meshgraphnets\normalization.py:73: where (from tensorflow.python.ops.array_ops) is deprecated and will be removed in a future version.
# Instructions for updating:
# Use tf.where in 2.0, which has the same broadcast rule as np.where
# WARNING:tensorflow:From C:\ProgramData\Anaconda3\envs\meshgraphnet\lib\site-packages\sonnet\python\modules\basic.py:127: calling TruncatedNormal.__init__ (from tensorflow.python.ops.init_ops) with dtype is deprecated and will be removed in a future version.
# Instructions for updating:
# Call initializer instance with the dtype argument instead of passing it to the constructor
# WARNING:tensorflow:From C:\ProgramData\Anaconda3\envs\meshgraphnet\lib\site-packages\sonnet\python\modules\basic.py:132: calling Zeros.__init__ (from tensorflow.python.ops.init_ops) with dtype is deprecated and will be removed in a future version.
# Instructions for updating:
# Call initializer instance with the dtype argument instead of passing it to the constructor
# WARNING:tensorflow:From C:\ProgramData\Anaconda3\envs\meshgraphnet\lib\site-packages\tensorflow_core\python\training\training_util.py:236: Variable.initialized_value (from tensorflow.python.ops.variables) is deprecated and will be removed in a future version.
# Instructions for updating:
# ...
# Use standard file utilities to get mtimes.
# WARNING:tensorflow:It seems that global step (tf.train.get_global_step) has not been increased. Current value (could be stable): 1000 vs previous value: 1000. You could increase the global step by passing tf.train.get_global_step() to Optimizer.apply_gradients or Optimizer.minimize.
# WARNING:tensorflow:It seems that global step (tf.train.get_global_step) has not been increased. Current value (could be stable): 1000 vs previous value: 1000. You could increase the global step by passing tf.train.get_global_step() to Optimizer.apply_gradients or Optimizer.minimize.
# WARNING:tensorflow:It seems that global step (tf.train.get_global_step) has not been increased. Current value (could be stable): 1000 vs previous value: 1000. You could increase the global step by passing tf.train.get_global_step() to Optimizer.apply_gradients or Optimizer.minimize.
# WARNING:tensorflow:It seems that global step (tf.train.get_global_step) has not been increased. Current value (could be stable): 1000 vs previous value: 1000. You could increase the global step by passing tf.train.get_global_step() to Optimizer.apply_gradients or Optimizer.minimize.
# WARNING:tensorflow:It seems that global step (tf.train.get_global_step) has not been increased. Current value (could be stable): 1000 vs previous value: 1000. You could increase the global step by passing tf.train.get_global_step() to Optimizer.apply_gradients or Optimizer.minimize.
# Error List: [3.3385084e-05, 3.9357856e-05, 6.773367e-05, 2.2222212e-05, 5.3550757e-05, 5.4357097e-05, 0.00015241904, 6.721832e-05, 2.7337564e-05, 0.00011248677]
# 2022-04-09 13:20:12.443569: W tensorflow/stream_executor/platform/default/dso_loader.cc:55] Could not load dynamic library 'cudart64_100.dll'; dlerror: cudart64_100.dll not found
# 2022-04-09 13:20:12.443783: I tensorflow/stream_executor/cuda/cudart_stub.cc:29] Ignore above cudart dlerror if you do not have a GPU set up on your machine.
# WARNING:tensorflow:From C:\ProgramData\Anaconda3\envs\meshgraphnet\lib\site-packages\tensorflow_core\python\ops\resource_variable_ops.py:1630: calling BaseResourceVariable.__init__ (from tensorflow.python.ops.resource_variable_ops) with constraint is deprecated and will be removed in a future version.
# Instructions for updating:
# If using Keras pass *_constraint arguments to layers.
# WARNING:tensorflow:From c:\Temp\HybridML\meshgraphnets\normalization.py:73: where (from tensorflow.python.ops.array_ops) is deprecated and will be removed in a future version.
# Instructions for updating:
# Use tf.where in 2.0, which has the same broadcast rule as np.where
# WARNING:tensorflow:From C:\ProgramData\Anaconda3\envs\meshgraphnet\lib\site-packages\sonnet\python\modules\basic.py:127: calling TruncatedNormal.__init__ (from tensorflow.python.ops.init_ops) with dtype is deprecated and will be removed in a future version.
# Instructions for updating:
# Call initializer instance with the dtype argument instead of passing it to the constructor
# WARNING:tensorflow:From C:\ProgramData\Anaconda3\envs\meshgraphnet\lib\site-packages\sonnet\python\modules\basic.py:132: calling Zeros.__init__ (from tensorflow.python.ops.init_ops) with dtype is deprecated and will be removed in a future version.
# Instructions for updating:
# Call initializer instance with the dtype argument instead of passing it to the constructor
# WARNING:tensorflow:From C:\ProgramData\Anaconda3\envs\meshgraphnet\lib\site-packages\tensorflow_core\python\training\training_util.py:236: Variable.initialized_value (from tensorflow.python.ops.variables) is deprecated and will be removed in a future version.
# Instructions for updating:
# Use Variable.read_value. Variables in 2.X are initialized automatically both in eager and graph (inside tf.defun) contexts.
# 2022-04-09 13:20:17.063332: W tensorflow/stream_executor/platform/default/dso_loader.cc:55] Could not load dynamic library 'nvcuda.dll'; dlerror: nvcuda.dll not found
# 2022-04-09 13:20:17.063586: E tensorflow/stream_executor/cuda/cuda_driver.cc:318] failed call to cuInit: UNKNOWN ERROR (303)
# 2022-04-09 13:20:17.067309: I tensorflow/stream_executor/cuda/cuda_diagnostics.cc:169] retrieving CUDA diagnostic information for host: DESKTOP-G86FQHS
# 2022-04-09 13:20:17.067518: I tensorflow/stream_executor/cuda/cuda_diagnostics.cc:176] hostname: DESKTOP-G86FQHS
# 2022-04-09 13:20:17.067838: I tensorflow/core/platform/cpu_feature_guard.cc:142] Your CPU supports instructions that this TensorFlow binary was not compiled to use: AVX2
# WARNING:tensorflow:From C:\ProgramData\Anaconda3\envs\meshgraphnet\lib\site-packages\tensorflow_core\python\training\saver.py:1069: get_checkpoint_mtimes (from tensorflow.python.training.checkpoint_management) is deprecated and will be removed in a future version.
# Instructions for updating:
# Use standard file utilities to get mtimes.
# WARNING:tensorflow:It seems that global step (tf.train.get_global_step) has not been increased. Current value (could be stable): 1000 vs previous value: 1000. You could increase the global step by passing tf.train.get_global_step() to Optimizer.apply_gradients or Optimizer.minimize.
# WARNING:tensorflow:It seems that global step (tf.train.get_global_step) has not been increased. Current value (could be stable): 1000 vs previous value: 1000. You could increase the global step by passing tf.train.get_global_step() to Optimizer.apply_gradients or Optimizer.minimize.
# WARNING:tensorflow:It seems that global step (tf.train.get_global_step) has not been increased. Current value (could be stable): 1000 vs previous value: 1000. You could increase the global step by passing tf.train.get_global_step() to Optimizer.apply_gradients or Optimizer.minimize.
# WARNING:tensorflow:It seems that global step (tf.train.get_global_step) has not been increased. Current value (could be stable): 1000 vs previous value: 1000. You could increase the global step by passing tf.train.get_global_step() to Optimizer.apply_gradients or Optimizer.minimize.
# WARNING:tensorflow:It seems that global step (tf.train.get_global_step) has not been increased. Current value (could be stable): 1000 vs previous value: 1000. You could increase the global step by passing tf.train.get_global_step() to Optimizer.apply_gradients or Optimizer.minimize.
# Error List: [0.00045811597, 0.0011999431, 0.00075545383, 0.00025943408, 0.00056350906, 0.0006204113, 0.0010453479, 0.00046010522, 0.0013134498, 9.552983e-05]
# 2022-04-09 13:20:18.572083: W tensorflow/stream_executor/platform/default/dso_loader.cc:55] Could not load dynamic library 'cudart64_100.dll'; dlerror: cudart64_100.dll not found
# 2022-04-09 13:20:18.572277: I tensorflow/stream_executor/cuda/cudart_stub.cc:29] Ignore above cudart dlerror if you do not have a GPU set up on your machine.
# WARNING:tensorflow:From C:\ProgramData\Anaconda3\envs\meshgraphnet\lib\site-packages\tensorflow_core\python\ops\resource_variable_ops.py:1630: calling BaseResourceVariable.__init__ (from tensorflow.python.ops.resource_variable_ops) with constraint is deprecated and will be removed in a future version.
# Instructions for updating:
# If using Keras pass *_constraint arguments to layers.
# WARNING:tensorflow:From c:\Temp\HybridML\meshgraphnets\normalization.py:73: where (from tensorflow.python.ops.array_ops) is deprecated and will be removed in a future version.
# Instructions for updating:
# Use tf.where in 2.0, which has the same broadcast rule as np.where
# WARNING:tensorflow:From C:\ProgramData\Anaconda3\envs\meshgraphnet\lib\site-packages\sonnet\python\modules\basic.py:127: calling TruncatedNormal.__init__ (from tensorflow.python.ops.init_ops) with dtype is deprecated and will be removed in a future version.
# Instructions for updating:
# Call initializer instance with the dtype argument instead of passing it to the constructor
# WARNING:tensorflow:From C:\ProgramData\Anaconda3\envs\meshgraphnet\lib\site-packages\sonnet\python\modules\basic.py:132: calling Zeros.__init__ (from tensorflow.python.ops.init_ops) with dtype is deprecated and will be removed in a future version.
# Instructions for updating:
# Call initializer instance with the dtype argument instead of passing it to the constructor
# WARNING:tensorflow:From C:\ProgramData\Anaconda3\envs\meshgraphnet\lib\site-packages\tensorflow_core\python\training\training_util.py:236: Variable.initialized_value (from tensorflow.python.ops.variables) is deprecated and will be removed in a future version.
# Instructions for updating:
# Use Variable.read_value. Variables in 2.X are initialized automatically both in eager and graph (inside tf.defun) contexts.
# 2022-04-09 13:20:23.159660: W tensorflow/stream_executor/platform/default/dso_loader.cc:55] Could not load dynamic library 'nvcuda.dll'; dlerror: nvcuda.dll not found
# 2022-04-09 13:20:23.159872: E tensorflow/stream_executor/cuda/cuda_driver.cc:318] failed call to cuInit: UNKNOWN ERROR (303)
# 2022-04-09 13:20:23.162740: I tensorflow/stream_executor/cuda/cuda_diagnostics.cc:169] retrieving CUDA diagnostic information for host: DESKTOP-G86FQHS
# 2022-04-09 13:20:23.162944: I tensorflow/stream_executor/cuda/cuda_diagnostics.cc:176] hostname: DESKTOP-G86FQHS
# 2022-04-09 13:20:23.163311: I tensorflow/core/platform/cpu_feature_guard.cc:142] Your CPU supports instructions that this TensorFlow binary was not compiled to use: AVX2
# WARNING:tensorflow:From C:\ProgramData\Anaconda3\envs\meshgraphnet\lib\site-packages\tensorflow_core\python\training\saver.py:1069: get_checkpoint_mtimes (from tensorflow.python.training.checkpoint_management) is deprecated and will be removed in a future version.
# Instructions for updating:
# Use standard file utilities to get mtimes.
# WARNING:tensorflow:It seems that global step (tf.train.get_global_step) has not been increased. Current value (could be stable): 1000 vs previous value: 1000. You could increase the global step by passing tf.train.get_global_step() to Optimizer.apply_gradients or Optimizer.minimize.
# WARNING:tensorflow:It seems that global step (tf.train.get_global_step) has not been increased. Current value (could be stable): 1000 vs previous value: 1000. You could increase the global step by passing tf.train.get_global_step() to Optimizer.apply_gradients or Optimizer.minimize.
# WARNING:tensorflow:It seems that global step (tf.train.get_global_step) has not been increased. Current value (could be stable): 1000 vs previous value: 1000. You could increase the global step by passing tf.train.get_global_step() to Optimizer.apply_gradients or Optimizer.minimize.
# WARNING:tensorflow:It seems that global step (tf.train.get_global_step) has not been increased. Current value (could be stable): 1000 vs previous value: 1000. You could increase the global step by passing tf.train.get_global_step() to Optimizer.apply_gradients or Optimizer.minimize.
# WARNING:tensorflow:It seems that global step (tf.train.get_global_step) has not been increased. Current value (could be stable): 1000 vs previous value: 1000. You could increase the global step by passing tf.train.get_global_step() to Optimizer.apply_gradients or Optimizer.minimize.
# Error List: [9.4532836e-05, 0.00030760444, 0.00013091887, 2.369477e-05, 0.00016514883, 7.860058e-05, 0.00025285044, 0.00024606744, 0.00020521008, 1.9587207e-05]
# 2022-04-09 13:20:24.656718: W tensorflow/stream_executor/platform/default/dso_loader.cc:55] Could not load dynamic library 'cudart64_100.dll'; dlerror: cudart64_100.dll not found
# 2022-04-09 13:20:24.656920: I tensorflow/stream_executor/cuda/cudart_stub.cc:29] Ignore above cudart dlerror if you do not have a GPU set up on your machine.
# WARNING:tensorflow:From C:\ProgramData\Anaconda3\envs\meshgraphnet\lib\site-packages\tensorflow_core\python\ops\resource_variable_ops.py:1630: calling BaseResourceVariable.__init__ (from tensorflow.python.ops.resource_variable_ops) with constraint is deprecated and will be removed in a future version.
# Instructions for updating:
# If using Keras pass *_constraint arguments to layers.
# WARNING:tensorflow:From c:\Temp\HybridML\meshgraphnets\normalization.py:73: where (from tensorflow.python.ops.array_ops) is deprecated and will be removed in a future version.
# Instructions for updating:
# Use tf.where in 2.0, which has the same broadcast rule as np.where
# WARNING:tensorflow:From C:\ProgramData\Anaconda3\envs\meshgraphnet\lib\site-packages\sonnet\python\modules\basic.py:127: calling TruncatedNormal.__init__ (from tensorflow.python.ops.init_ops) with dtype is deprecated and will be removed in a future version.
# Instructions for updating:
# Call initializer instance with the dtype argument instead of passing it to the constructor
# WARNING:tensorflow:From C:\ProgramData\Anaconda3\envs\meshgraphnet\lib\site-packages\sonnet\python\modules\basic.py:132: calling Zeros.__init__ (from tensorflow.python.ops.init_ops) with dtype is deprecated and will be removed in a future version.
# Instructions for updating:
# Call initializer instance with the dtype argument instead of passing it to the constructor
# WARNING:tensorflow:From C:\ProgramData\Anaconda3\envs\meshgraphnet\lib\site-packages\tensorflow_core\python\training\training_util.py:236: Variable.initialized_value (from tensorflow.python.ops.variables) is deprecated and will be removed in a future version.
# Instructions for updating:
# Use Variable.read_value. Variables in 2.X are initialized automatically both in eager and graph (inside tf.defun) contexts.
# 2022-04-09 13:20:29.243481: W tensorflow/stream_executor/platform/default/dso_loader.cc:55] Could not load dynamic library 'nvcuda.dll'; dlerror: nvcuda.dll not found
# 2022-04-09 13:20:29.243664: E tensorflow/stream_executor/cuda/cuda_driver.cc:318] failed call to cuInit: UNKNOWN ERROR (303)
# 2022-04-09 13:20:29.247342: I tensorflow/stream_executor/cuda/cuda_diagnostics.cc:169] retrieving CUDA diagnostic information for host: DESKTOP-G86FQHS
# 2022-04-09 13:20:29.247598: I tensorflow/stream_executor/cuda/cuda_diagnostics.cc:176] hostname: DESKTOP-G86FQHS
# 2022-04-09 13:20:29.247988: I tensorflow/core/platform/cpu_feature_guard.cc:142] Your CPU supports instructions that this TensorFlow binary was not compiled to use: AVX2
# WARNING:tensorflow:From C:\ProgramData\Anaconda3\envs\meshgraphnet\lib\site-packages\tensorflow_core\python\training\saver.py:1069: get_checkpoint_mtimes (from tensorflow.python.training.checkpoint_management) is deprecated and will be removed in a future version.
# Instructions for updating:
# Use standard file utilities to get mtimes.
# WARNING:tensorflow:It seems that global step (tf.train.get_global_step) has not been increased. Current value (could be stable): 1000 vs previous value: 1000. You could increase the global step by passing tf.train.get_global_step() to Optimizer.apply_gradients or Optimizer.minimize.
# WARNING:tensorflow:It seems that global step (tf.train.get_global_step) has not been increased. Current value (could be stable): 1000 vs previous value: 1000. You could increase the global step by passing tf.train.get_global_step() to Optimizer.apply_gradients or Optimizer.minimize.
# WARNING:tensorflow:It seems that global step (tf.train.get_global_step) has not been increased. Current value (could be stable): 1000 vs previous value: 1000. You could increase the global step by passing tf.train.get_global_step() to Optimizer.apply_gradients or Optimizer.minimize.
# WARNING:tensorflow:It seems that global step (tf.train.get_global_step) has not been increased. Current value (could be stable): 1000 vs previous value: 1000. You could increase the global step by passing tf.train.get_global_step() to Optimizer.apply_gradients or Optimizer.minimize.
# WARNING:tensorflow:It seems that global step (tf.train.get_global_step) has not been increased. Current value (could be stable): 1000 vs previous value: 1000. You could increase the global step by passing tf.train.get_global_step() to Optimizer.apply_gradients or Optimizer.minimize.
# Error List: [8.4463914e-05, 0.0002542258, 6.0706687e-05, 2.664106e-05, 8.649069e-05, 0.000100558944, 0.00016311587, 0.00019313363, 0.00019282204, 1.8817665e-05]

# %%
# 2D model 2:

run_2d_experiments_on_samples(data_name = "data_2d_2",
                              n_initial_steps=100,
                              num_training_steps=8000,
                              message_passing_steps=6)
# Out:
# 2022-04-09 08:18:28.133111: W tensorflow/stream_executor/platform/default/dso_loader.cc:55] Could not load dynamic library 'cudart64_100.dll'; dlerror: cudart64_100.dll not found
# 2022-04-09 08:18:28.133298: I tensorflow/stream_executor/cuda/cudart_stub.cc:29] Ignore above cudart dlerror if you do not have a GPU set up on your machine.
# WARNING:tensorflow:From C:\ProgramData\Anaconda3\envs\meshgraphnet\lib\site-packages\tensorflow_core\python\ops\resource_variable_ops.py:1630: calling BaseResourceVariable.__init__ (from tensorflow.python.ops.resource_variable_ops) with constraint is deprecated and will be removed in a future version.
# Instructions for updating:
# If using Keras pass *_constraint arguments to layers.
# WARNING:tensorflow:From C:\ProgramData\Anaconda3\envs\meshgraphnet\lib\site-packages\tensorflow_core\python\data\util\random_seed.py:58: where (from tensorflow.python.ops.array_ops) is deprecated and will be removed in a future version.
# Instructions for updating:
# Use tf.where in 2.0, which has the same broadcast rule as np.where
# WARNING:tensorflow:From C:\ProgramData\Anaconda3\envs\meshgraphnet\lib\site-packages\sonnet\python\modules\basic.py:127: calling TruncatedNormal.__init__ (from tensorflow.python.ops.init_ops) with dtype is deprecated and will be removed in a future version.
# Instructions for updating:
# Call initializer instance with the dtype argument instead of passing it to the constructor
# WARNING:tensorflow:From C:\ProgramData\Anaconda3\envs\meshgraphnet\lib\site-packages\sonnet\python\modules\basic.py:132: calling Zeros.__init__ (from tensorflow.python.ops.init_ops) with dtype is deprecated and will be removed in a future version.
# Instructions for updating:
# Call initializer instance with the dtype argument instead of passing it to the constructor
# WARNING:tensorflow:From C:\ProgramData\Anaconda3\envs\meshgraphnet\lib\site-packages\tensorflow_core\python\training\training_util.py:236: Variable.initialized_value (from tensorflow.python.ops.variables) is deprecated and will be removed in a future version.
# Instructions for updating:
# Use Variable.read_value. Variables in 2.X are initialized automatically both in eager and graph (inside tf.defun) contexts.
# 2022-04-09 08:18:40.565385: W tensorflow/stream_executor/platform/default/dso_loader.cc:55] Could not load dynamic library 'nvcuda.dll'; dlerror: nvcuda.dll not found
# 2022-04-09 08:18:40.565600: E tensorflow/stream_executor/cuda/cuda_driver.cc:318] failed call to cuInit: UNKNOWN ERROR (303)
# 2022-04-09 08:18:40.569515: I tensorflow/stream_executor/cuda/cuda_diagnostics.cc:169] retrieving CUDA diagnostic information for host: DESKTOP-G86FQHS
# 2022-04-09 08:18:40.570007: I tensorflow/stream_executor/cuda/cuda_diagnostics.cc:176] hostname: DESKTOP-G86FQHS
# 2022-04-09 08:18:40.570482: I tensorflow/core/platform/cpu_feature_guard.cc:142] Your CPU supports instructions that this TensorFlow binary was not compiled to use: AVX2
# Step 0: Loss 9.128559
#
# Step 100: Loss 2.7701495
#
# Step 200: Loss 2.8450274
#
# Step 300: Loss 1.5893373
#
# Step 400: Loss 0.75754565
#
# Step 500: Loss 0.7950873
#
# Step 600: Loss 1.155053
#
# Step 700: Loss 1.1005934
#
# Step 800: Loss 0.6642767
#
# Step 900: Loss 0.54998666
#
# Step 1000: Loss 0.4873568
#
# Step 1100: Loss 0.49280757
#
# Step 1200: Loss 0.4063722
#
# Step 1300: Loss 0.6858919
#
# Step 1400: Loss 0.5571197
#
# Step 1500: Loss 1.33381
#
# Step 1600: Loss 0.391015
#
# Step 1700: Loss 0.33621514
#
# WARNING:tensorflow:From C:\ProgramData\Anaconda3\envs\meshgraphnet\lib\site-packages\tensorflow_core\python\training\saver.py:963: remove_checkpoint (from tensorflow.python.training.checkpoint_management) is deprecated and will be removed in a future version.
# Instructions for updating:
# Use standard file APIs to delete files with this prefix.
# Step 1800: Loss 0.6039845
#
# Step 1900: Loss 0.7257321
#
# Step 2000: Loss 0.43749008
#
# Step 2100: Loss 1.0393485
#
# Step 2200: Loss 0.8548569
#
# Step 2300: Loss 0.47875902
#
# Step 2400: Loss 0.23136029
#
# Step 2500: Loss 0.87177163
#
# Step 2600: Loss 0.2841196
#
# Step 2700: Loss 0.23258244
#
# Step 2800: Loss 0.26731607
#
# Step 2900: Loss 0.58801603
#
# Step 3000: Loss 0.17401055
#
# Step 3100: Loss 0.15514767
#
# Step 3200: Loss 0.18354204
#
# Step 3300: Loss 0.239227
#
# Step 3400: Loss 0.3253683
#
# Step 3500: Loss 0.1670006
#
# Step 3600: Loss 0.24727063
#
# Step 3700: Loss 0.4477841
#
# Step 3800: Loss 0.8694577
#
# Step 3900: Loss 0.46469736
#
# Step 4000: Loss 0.116466634
#
# Step 4100: Loss 0.8861711
#
# Step 4200: Loss 0.1139587
#
# Step 4300: Loss 0.42539313
#
# Step 4400: Loss 1.0991217
#
# Step 4500: Loss 0.9849912
#
# Step 4600: Loss 0.19414629
#
# Step 4700: Loss 0.16942994
#
# Step 4800: Loss 0.2552693
#
# Step 4900: Loss 0.21736982
#
# Step 5000: Loss 0.29223013
#
# Step 5100: Loss 0.790009
#
# Step 5200: Loss 0.15267774
#
# Step 5300: Loss 1.0260527
#
# Step 5400: Loss 0.8738084
#
# Step 5500: Loss 0.9826256
#
# Step 5600: Loss 0.6059031
#
# Step 5700: Loss 0.64467055
#
# Step 5800: Loss 1.0806332
#
# Step 5900: Loss 0.09911765
#
# Step 6000: Loss 0.8131976
#
# Step 6100: Loss 0.12499584
#
# Step 6200: Loss 0.14221223
#
# Step 6300: Loss 0.6843877
#
# Step 6400: Loss 0.11824495
#
# Step 6500: Loss 0.10521165
#
# Step 6600: Loss 0.89743745
#
# Step 6700: Loss 0.12382221
#
# Step 6800: Loss 0.6604957
#
# Step 6900: Loss 0.8567007
#
# Step 7000: Loss 0.446811
#
# Step 7100: Loss 0.8358853
#
# Step 7200: Loss 0.101431474
#
# Step 7300: Loss 0.09464114
#
# Step 7400: Loss 0.4569227
#
# Step 7500: Loss 0.07195565
#
# Step 7600: Loss 0.48286912
#
# Step 7700: Loss 0.09300182
#
# Step 7800: Loss 1.0566057
#
# Step 7900: Loss 0.071263485
#
# Training complete.
# 2022-04-09 08:30:30.503865: W tensorflow/stream_executor/platform/default/dso_loader.cc:55] Could not load dynamic library 'cudart64_100.dll'; dlerror: cudart64_100.dll not found
# 2022-04-09 08:30:30.504054: I tensorflow/stream_executor/cuda/cudart_stub.cc:29] Ignore above cudart dlerror if you do not have a GPU set up on your machine.
# WARNING:tensorflow:From C:\ProgramData\Anaconda3\envs\meshgraphnet\lib\site-packages\tensorflow_core\python\ops\resource_variable_ops.py:1630: calling BaseResourceVariable.__init__ (from tensorflow.python.ops.resource_variable_ops) with constraint is deprecated and will be removed in a future version.
# Instructions for updating:
# If using Keras pass *_constraint arguments to layers.
# WARNING:tensorflow:From C:\ProgramData\Anaconda3\envs\meshgraphnet\lib\site-packages\tensorflow_core\python\data\util\random_seed.py:58: where (from tensorflow.python.ops.array_ops) is deprecated and will be removed in a future version.
# Instructions for updating:
# Use tf.where in 2.0, which has the same broadcast rule as np.where
# WARNING:tensorflow:From C:\ProgramData\Anaconda3\envs\meshgraphnet\lib\site-packages\sonnet\python\modules\basic.py:127: calling TruncatedNormal.__init__ (from tensorflow.python.ops.init_ops) with dtype is deprecated and will be removed in a future version.
# Instructions for updating:
# Call initializer instance with the dtype argument instead of passing it to the constructor
# WARNING:tensorflow:From C:\ProgramData\Anaconda3\envs\meshgraphnet\lib\site-packages\sonnet\python\modules\basic.py:132: calling Zeros.__init__ (from tensorflow.python.ops.init_ops) with dtype is deprecated and will be removed in a future version.
# Instructions for updating:
# Call initializer instance with the dtype argument instead of passing it to the constructor
# WARNING:tensorflow:From C:\ProgramData\Anaconda3\envs\meshgraphnet\lib\site-packages\tensorflow_core\python\training\training_util.py:236: Variable.initialized_value (from tensorflow.python.ops.variables) is deprecated and will be removed in a future version.
# Instructions for updating:
# Use Variable.read_value. Variables in 2.X are initialized automatically both in eager and graph (inside tf.defun) contexts.
# 2022-04-09 08:30:39.516312: W tensorflow/stream_executor/platform/default/dso_loader.cc:55] Could not load dynamic library 'nvcuda.dll'; dlerror: nvcuda.dll not found
# 2022-04-09 08:30:39.516513: E tensorflow/stream_executor/cuda/cuda_driver.cc:318] failed call to cuInit: UNKNOWN ERROR (303)
# 2022-04-09 08:30:39.520101: I tensorflow/stream_executor/cuda/cuda_diagnostics.cc:169] retrieving CUDA diagnostic information for host: DESKTOP-G86FQHS
# 2022-04-09 08:30:39.520373: I tensorflow/stream_executor/cuda/cuda_diagnostics.cc:176] hostname: DESKTOP-G86FQHS
# 2022-04-09 08:30:39.520722: I tensorflow/core/platform/cpu_feature_guard.cc:142] Your CPU supports instructions that this TensorFlow binary was not compiled to use: AVX2
# Step 0: Loss 6.590045
#
# Step 100: Loss 4.2692523
#
# Step 200: Loss 0.55155027
#
# Step 300: Loss 0.23171075
#
# Step 400: Loss 0.19346264
#
# Step 500: Loss 0.15520452
#
# Step 600: Loss 0.2403162
#
# Step 700: Loss 0.0438696
#
# Step 800: Loss 0.072005674
#
# Step 900: Loss 0.06258107
#
# Step 1000: Loss 0.02983563
#
# Step 1100: Loss 0.07545968
#
# Step 1200: Loss 0.025331762
#
# Step 1300: Loss 0.03873644
#
# Step 1400: Loss 0.040443625
#
# Step 1500: Loss 0.16993408
#
# Step 1600: Loss 0.028071173
#
# Step 1700: Loss 0.04987915
#
# Step 1800: Loss 0.060455013
#
# WARNING:tensorflow:From C:\ProgramData\Anaconda3\envs\meshgraphnet\lib\site-packages\tensorflow_core\python\training\saver.py:963: remove_checkpoint (from tensorflow.python.training.checkpoint_management) is deprecated and will be removed in a future version.
# Instructions for updating:
# Use standard file APIs to delete files with this prefix.
# Step 1900: Loss 0.019892959
#
# Step 2000: Loss 0.017280173
#
# Step 2100: Loss 0.074130416
#
# Step 2200: Loss 0.11095079
#
# Step 2300: Loss 0.067686334
#
# Step 2400: Loss 0.019673267
#
# Step 2500: Loss 0.04683173
#
# Step 2600: Loss 0.0114396885
#
# Step 2700: Loss 0.0104071535
#
# Step 2800: Loss 0.010768881
#
# Step 2900: Loss 0.044813663
#
# Step 3000: Loss 0.012575469
#
# Step 3100: Loss 0.013228429
#
# Step 3200: Loss 0.007846594
#
# Step 3300: Loss 0.0077948496
#
# Step 3400: Loss 0.012854559
#
# Step 3500: Loss 0.021735981
#
# Step 3600: Loss 0.03448784
#
# Step 3700: Loss 0.022627115
#
# Step 3800: Loss 0.036337465
#
# Step 3900: Loss 0.014933156
#
# Step 4000: Loss 0.006251853
#
# Step 4100: Loss 0.010469368
#
# Step 4200: Loss 0.005677062
#
# Step 4300: Loss 0.0165915
#
# Step 4400: Loss 0.026693072
#
# Step 4500: Loss 0.021911573
#
# Step 4600: Loss 0.0065434277
#
# Step 4700: Loss 0.0058096065
#
# Step 4800: Loss 0.0073688254
#
# Step 4900: Loss 0.04013614
#
# Step 5000: Loss 0.0052045477
#
# Step 5100: Loss 0.0082829995
#
# Step 5200: Loss 0.004872253
#
# Step 5300: Loss 0.005264863
#
# Step 5400: Loss 0.00493981
#
# Step 5500: Loss 0.00944137
#
# Step 5600: Loss 0.0103954105
#
# Step 5700: Loss 0.013212627
#
# Step 5800: Loss 0.14005186
#
# Step 5900: Loss 0.0050138277
#
# Step 6000: Loss 0.0058139833
#
# Step 6100: Loss 0.0034797997
#
# Step 6200: Loss 0.0044835787
#
# Step 6300: Loss 0.0058708405
#
# Step 6400: Loss 0.012802724
#
# Step 6500: Loss 0.020549074
#
# Step 6600: Loss 0.06667995
#
# Step 6700: Loss 0.004920975
#
# Step 6800: Loss 0.0041232216
#
# Step 6900: Loss 0.005199261
#
# Step 7000: Loss 0.0062476336
#
# Step 7100: Loss 0.0094556445
#
# Step 7200: Loss 0.0041845115
#
# Step 7300: Loss 0.0027194994
#
# Step 7400: Loss 0.0041720495
#
# Step 7500: Loss 0.004983362
#
# Step 7600: Loss 0.022921761
#
# Step 7700: Loss 0.0457057
#
# Step 7800: Loss 0.0054249116
#
# Step 7900: Loss 0.0046457457
#
# Training complete.
# 2022-04-09 08:42:14.548533: W tensorflow/stream_executor/platform/default/dso_loader.cc:55] Could not load dynamic library 'cudart64_100.dll'; dlerror: cudart64_100.dll not found
# 2022-04-09 08:42:14.548798: I tensorflow/stream_executor/cuda/cudart_stub.cc:29] Ignore above cudart dlerror if you do not have a GPU set up on your machine.
# WARNING:tensorflow:From C:\ProgramData\Anaconda3\envs\meshgraphnet\lib\site-packages\tensorflow_core\python\ops\resource_variable_ops.py:1630: calling BaseResourceVariable.__init__ (from tensorflow.python.ops.resource_variable_ops) with constraint is deprecated and will be removed in a future version.
# Instructions for updating:
# If using Keras pass *_constraint arguments to layers.
# WARNING:tensorflow:From C:\ProgramData\Anaconda3\envs\meshgraphnet\lib\site-packages\tensorflow_core\python\data\util\random_seed.py:58: where (from tensorflow.python.ops.array_ops) is deprecated and will be removed in a future version.
# Instructions for updating:
# Use tf.where in 2.0, which has the same broadcast rule as np.where
# WARNING:tensorflow:From C:\ProgramData\Anaconda3\envs\meshgraphnet\lib\site-packages\sonnet\python\modules\basic.py:127: calling TruncatedNormal.__init__ (from tensorflow.python.ops.init_ops) with dtype is deprecated and will be removed in a future version.
# Instructions for updating:
# Call initializer instance with the dtype argument instead of passing it to the constructor
# WARNING:tensorflow:From C:\ProgramData\Anaconda3\envs\meshgraphnet\lib\site-packages\sonnet\python\modules\basic.py:132: calling Zeros.__init__ (from tensorflow.python.ops.init_ops) with dtype is deprecated and will be removed in a future version.
# Instructions for updating:
# Call initializer instance with the dtype argument instead of passing it to the constructor
# WARNING:tensorflow:From C:\ProgramData\Anaconda3\envs\meshgraphnet\lib\site-packages\tensorflow_core\python\training\training_util.py:236: Variable.initialized_value (from tensorflow.python.ops.variables) is deprecated and will be removed in a future version.
# Instructions for updating:
# Use Variable.read_value. Variables in 2.X are initialized automatically both in eager and graph (inside tf.defun) contexts.
# 2022-04-09 08:42:23.780789: W tensorflow/stream_executor/platform/default/dso_loader.cc:55] Could not load dynamic library 'nvcuda.dll'; dlerror: nvcuda.dll not found
# 2022-04-09 08:42:23.781041: E tensorflow/stream_executor/cuda/cuda_driver.cc:318] failed call to cuInit: UNKNOWN ERROR (303)
# 2022-04-09 08:42:23.784524: I tensorflow/stream_executor/cuda/cuda_diagnostics.cc:169] retrieving CUDA diagnostic information for host: DESKTOP-G86FQHS
# 2022-04-09 08:42:23.784783: I tensorflow/stream_executor/cuda/cuda_diagnostics.cc:176] hostname: DESKTOP-G86FQHS
# 2022-04-09 08:42:23.785144: I tensorflow/core/platform/cpu_feature_guard.cc:142] Your CPU supports instructions that this TensorFlow binary was not compiled to use: AVX2
# Step 100: Loss 3.019867
#
# Step 200: Loss 1.9140805
#
# Step 300: Loss 0.5508179
#
# Step 400: Loss 0.25225306
#
# Step 500: Loss 0.1840325
#
# Step 600: Loss 0.17710812
#
# Step 700: Loss 0.12600736
#
# Step 800: Loss 0.08956322
#
# Step 900: Loss 0.06769038
#
# Step 1000: Loss 0.05780293
#
# Step 1100: Loss 0.061235696
#
# Step 1200: Loss 0.041485768
#
# Step 1300: Loss 0.033449236
#
# Step 1400: Loss 0.039787967
#
# Step 1500: Loss 0.085911684
#
# Step 1600: Loss 0.025800405
#
# Step 1700: Loss 0.035101745
#
# WARNING:tensorflow:From C:\ProgramData\Anaconda3\envs\meshgraphnet\lib\site-packages\tensorflow_core\python\training\saver.py:963: remove_checkpoint (from tensorflow.python.training.checkpoint_management) is deprecated and will be removed in a future version.
# Instructions for updating:
# Use standard file APIs to delete files with this prefix.
# Step 1800: Loss 0.030217571
#
# Step 1900: Loss 0.022884991
#
# Step 2000: Loss 0.05106843
#
# Step 2100: Loss 0.047160406
#
# Step 2200: Loss 0.02273354
#
# Step 2300: Loss 0.021287045
#
# Step 2400: Loss 0.04615549
#
# Step 2500: Loss 0.022748962
#
# Step 2600: Loss 0.00977529
#
# Step 2700: Loss 0.012132576
#
# Step 2800: Loss 0.05663058
#
# Step 2900: Loss 0.029753862
#
# Step 3000: Loss 0.011040643
#
# Step 3100: Loss 0.011368151
#
# Step 3200: Loss 0.012050316
#
# Step 3300: Loss 0.007605693
#
# Step 3400: Loss 0.018469978
#
# Step 3500: Loss 0.0126772355
#
# Step 3600: Loss 0.006755501
#
# Step 3700: Loss 0.15323667
#
# Step 3800: Loss 0.022578422
#
# Step 3900: Loss 0.010990536
#
# Step 4000: Loss 0.007474026
#
# Step 4100: Loss 0.0076299063
#
# Step 4200: Loss 0.0064251577
#
# Step 4300: Loss 0.007324687
#
# Step 4400: Loss 0.008119077
#
# Step 4500: Loss 0.013130501
#
# Step 4600: Loss 0.007972171
#
# Step 4700: Loss 0.020986514
#
# Step 4800: Loss 0.027676996
#
# Step 4900: Loss 0.031760007
#
# Step 5000: Loss 0.0048762583
#
# Step 5100: Loss 0.005861336
#
# Step 5200: Loss 0.0059256353
#
# Step 5300: Loss 0.0048154127
#
# Step 5400: Loss 0.004281146
#
# Step 5500: Loss 0.0050149537
#
# Step 5600: Loss 0.010461428
#
# Step 5700: Loss 0.007487158
#
# Step 5800: Loss 0.3068123
#
# Step 5900: Loss 0.0048622782
#
# Step 6000: Loss 0.005002254
#
# Step 6100: Loss 0.003170592
#
# Step 6200: Loss 0.0060055917
#
# Step 6300: Loss 0.01416381
#
# Step 6400: Loss 0.006804371
#
# Step 6500: Loss 0.006551206
#
# Step 6600: Loss 0.09877938
#
# Step 6700: Loss 0.006653971
#
# Step 6800: Loss 0.0040655634
#
# Step 6900: Loss 0.015082688
#
# Step 7000: Loss 0.004487922
#
# Step 7100: Loss 0.0030921209
#
# Step 7200: Loss 0.003702796
#
# Step 7300: Loss 0.0032467053
#
# Step 7400: Loss 0.028182417
#
# Step 7500: Loss 0.026823044
#
# Step 7600: Loss 0.0033686617
#
# Step 7700: Loss 0.0023778868
#
# Step 7800: Loss 0.0032692014
#
# Step 7900: Loss 0.005419278
#
# Training complete.
# 2022-04-09 08:54:19.104052: W tensorflow/stream_executor/platform/default/dso_loader.cc:55] Could not load dynamic library 'cudart64_100.dll'; dlerror: cudart64_100.dll not found
# 2022-04-09 08:54:19.104233: I tensorflow/stream_executor/cuda/cudart_stub.cc:29] Ignore above cudart dlerror if you do not have a GPU set up on your machine.
# WARNING:tensorflow:From C:\ProgramData\Anaconda3\envs\meshgraphnet\lib\site-packages\tensorflow_core\python\ops\resource_variable_ops.py:1630: calling BaseResourceVariable.__init__ (from tensorflow.python.ops.resource_variable_ops) with constraint is deprecated and will be removed in a future version.
# Instructions for updating:
# If using Keras pass *_constraint arguments to layers.
# WARNING:tensorflow:From c:\Temp\HybridML\meshgraphnets\normalization.py:73: where (from tensorflow.python.ops.array_ops) is deprecated and will be removed in a future version.
# Instructions for updating:
# Use tf.where in 2.0, which has the same broadcast rule as np.where
# WARNING:tensorflow:From C:\ProgramData\Anaconda3\envs\meshgraphnet\lib\site-packages\sonnet\python\modules\basic.py:127: calling TruncatedNormal.__init__ (from tensorflow.python.ops.init_ops) with dtype is deprecated and will be removed in a future version.
# Instructions for updating:
# Call initializer instance with the dtype argument instead of passing it to the constructor
# WARNING:tensorflow:From C:\ProgramData\Anaconda3\envs\meshgraphnet\lib\site-packages\sonnet\python\modules\basic.py:132: calling Zeros.__init__ (from tensorflow.python.ops.init_ops) with dtype is deprecated and will be removed in a future version.
# Instructions for updating:
# Call initializer instance with the dtype argument instead of passing it to the constructor
# WARNING:tensorflow:From C:\ProgramData\Anaconda3\envs\meshgraphnet\lib\site-packages\tensorflow_core\python\training\training_util.py:236: Variable.initialized_value (from tensorflow.python.ops.variables) is deprecated and will be removed in a future version.
# Instructions for updating:
# Use Variable.read_value. Variables in 2.X are initialized automatically both in eager and graph (inside tf.defun) contexts.
# 2022-04-09 08:54:24.077860: W tensorflow/stream_executor/platform/default/dso_loader.cc:55] Could not load dynamic library 'nvcuda.dll'; dlerror: nvcuda.dll not found
# 2022-04-09 08:54:24.078050: E tensorflow/stream_executor/cuda/cuda_driver.cc:318] failed call to cuInit: UNKNOWN ERROR (303)
# 2022-04-09 08:54:24.081556: I tensorflow/stream_executor/cuda/cuda_diagnostics.cc:169] retrieving CUDA diagnostic information for host: DESKTOP-G86FQHS
# 2022-04-09 08:54:24.081812: I tensorflow/stream_executor/cuda/cuda_diagnostics.cc:176] hostname: DESKTOP-G86FQHS
# 2022-04-09 08:54:24.082124: I tensorflow/core/platform/cpu_feature_guard.cc:142] Your CPU supports instructions that this TensorFlow binary was not compiled to use: AVX2
# WARNING:tensorflow:From C:\ProgramData\Anaconda3\envs\meshgraphnet\lib\site-packages\tensorflow_core\python\training\saver.py:1069: get_checkpoint_mtimes (from tensorflow.python.training.checkpoint_management) is deprecated and will be removed in a future version.
# Instructions for updating:
# Use standard file utilities to get mtimes.
# WARNING:tensorflow:It seems that global step (tf.train.get_global_step) has not been increased. Current value (could be stable): 8000 vs previous value: 8000. You could increase the global step by passing tf.train.get_global_step() to Optimizer.apply_gradients or Optimizer.minimize.
# WARNING:tensorflow:It seems that global step (tf.train.get_global_step) has not been increased. Current value (could be stable): 8000 vs previous value: 8000. You could increase the global step by passing tf.train.get_global_step() to Optimizer.apply_gradients or Optimizer.minimize.
# WARNING:tensorflow:It seems that global step (tf.train.get_global_step) has not been increased. Current value (could be stable): 8000 vs previous value: 8000. You could increase the global step by passing tf.train.get_global_step() to Optimizer.apply_gradients or Optimizer.minimize.
# Error List: [4.361036e-06, 1.3352548e-05, 1.8026778e-05, 5.391614e-06]
# 2022-04-09 08:54:25.866572: W tensorflow/stream_executor/platform/default/dso_loader.cc:55] Could not load dynamic library 'cudart64_100.dll'; dlerror: cudart64_100.dll not found
# 2022-04-09 08:54:25.866760: I tensorflow/stream_executor/cuda/cudart_stub.cc:29] Ignore above cudart dlerror if you do not have a GPU set up on your machine.
# WARNING:tensorflow:From C:\ProgramData\Anaconda3\envs\meshgraphnet\lib\site-packages\tensorflow_core\python\ops\resource_variable_ops.py:1630: calling BaseResourceVariable.__init__ (from tensorflow.python.ops.resource_variable_ops) with constraint is deprecated and will be removed in a future version.
# Instructions for updating:
# If using Keras pass *_constraint arguments to layers.
# WARNING:tensorflow:From c:\Temp\HybridML\meshgraphnets\normalization.py:73: where (from tensorflow.python.ops.array_ops) is deprecated and will be removed in a future version.
# Instructions for updating:
# Use tf.where in 2.0, which has the same broadcast rule as np.where
# WARNING:tensorflow:From C:\ProgramData\Anaconda3\envs\meshgraphnet\lib\site-packages\sonnet\python\modules\basic.py:127: calling TruncatedNormal.__init__ (from tensorflow.python.ops.init_ops) with dtype is deprecated and will be removed in a future version.
# Instructions for updating:
# Call initializer instance with the dtype argument instead of passing it to the constructor
# WARNING:tensorflow:From C:\ProgramData\Anaconda3\envs\meshgraphnet\lib\site-packages\sonnet\python\modules\basic.py:132: calling Zeros.__init__ (from tensorflow.python.ops.init_ops) with dtype is deprecated and will be removed in a future version.
# Instructions for updating:
# Call initializer instance with the dtype argument instead of passing it to the constructor
# WARNING:tensorflow:From C:\ProgramData\Anaconda3\envs\meshgraphnet\lib\site-packages\tensorflow_core\python\training\training_util.py:236: Variable.initialized_value (from tensorflow.python.ops.variables) is deprecated and will be removed in a future version.
# Instructions for updating:
# Use Variable.read_value. Variables in 2.X are initialized automatically both in eager and graph (inside tf.defun) contexts.
# 2022-04-09 08:54:31.029082: W tensorflow/stream_executor/platform/default/dso_loader.cc:55] Could not load dynamic library 'nvcuda.dll'; dlerror: nvcuda.dll not found
# 2022-04-09 08:54:31.029267: E tensorflow/stream_executor/cuda/cuda_driver.cc:318] failed call to cuInit: UNKNOWN ERROR (303)
# 2022-04-09 08:54:31.032714: I tensorflow/stream_executor/cuda/cuda_diagnostics.cc:169] retrieving CUDA diagnostic information for host: DESKTOP-G86FQHS
# 2022-04-09 08:54:31.032928: I tensorflow/stream_executor/cuda/cuda_diagnostics.cc:176] hostname: DESKTOP-G86FQHS
# 2022-04-09 08:54:31.033282: I tensorflow/core/platform/cpu_feature_guard.cc:142] Your CPU supports instructions that this TensorFlow binary was not compiled to use: AVX2
# WARNING:tensorflow:From C:\ProgramData\Anaconda3\envs\meshgraphnet\lib\site-packages\tensorflow_core\python\training\saver.py:1069: get_checkpoint_mtimes (from tensorflow.python.training.checkpoint_management) is deprecated and will be removed in a future version.
# Instructions for updating:
# Use standard file utilities to get mtimes.
# WARNING:tensorflow:It seems that global step (tf.train.get_global_step) has not been increased. Current value (could be stable): 8000 vs previous value: 8000. You could increase the global step by passing tf.train.get_global_step() to Optimizer.apply_gradients or Optimizer.minimize.
# WARNING:tensorflow:It seems that global step (tf.train.get_global_step) has not been increased. Current value (could be stable): 8000 vs previous value: 8000. You could increase the global step by passing tf.train.get_global_step() to Optimizer.apply_gradients or Optimizer.minimize.
# WARNING:tensorflow:It seems that global step (tf.train.get_global_step) has not been increased. Current value (could be stable): 8000 vs previous value: 8000. You could increase the global step by passing tf.train.get_global_step() to Optimizer.apply_gradients or Optimizer.minimize.
# Error List: [2.0789082e-07, 1.9680702e-07, 2.176198e-07, 1.736925e-07]
# 2022-04-09 08:54:32.776318: W tensorflow/stream_executor/platform/default/dso_loader.cc:55] Could not load dynamic library 'cudart64_100.dll'; dlerror: cudart64_100.dll not found
# 2022-04-09 08:54:32.776502: I tensorflow/stream_executor/cuda/cudart_stub.cc:29] Ignore above cudart dlerror if you do not have a GPU set up on your machine.
# WARNING:tensorflow:From C:\ProgramData\Anaconda3\envs\meshgraphnet\lib\site-packages\tensorflow_core\python\ops\resource_variable_ops.py:1630: calling BaseResourceVariable.__init__ (from tensorflow.python.ops.resource_variable_ops) with constraint is deprecated and will be removed in a future version.
# Instructions for updating:
# If using Keras pass *_constraint arguments to layers.
# WARNING:tensorflow:From c:\Temp\HybridML\meshgraphnets\normalization.py:73: where (from tensorflow.python.ops.array_ops) is deprecated and will be removed in a future version.
# Instructions for updating:
# Use tf.where in 2.0, which has the same broadcast rule as np.where
# WARNING:tensorflow:From C:\ProgramData\Anaconda3\envs\meshgraphnet\lib\site-packages\sonnet\python\modules\basic.py:127: calling TruncatedNormal.__init__ (from tensorflow.python.ops.init_ops) with dtype is deprecated and will be removed in a future version.
# Instructions for updating:
# Call initializer instance with the dtype argument instead of passing it to the constructor
# WARNING:tensorflow:From C:\ProgramData\Anaconda3\envs\meshgraphnet\lib\site-packages\sonnet\python\modules\basic.py:132: calling Zeros.__init__ (from tensorflow.python.ops.init_ops) with dtype is deprecated and will be removed in a future version.
# Instructions for updating:
# Call initializer instance with the dtype argument instead of passing it to the constructor
# WARNING:tensorflow:From C:\ProgramData\Anaconda3\envs\meshgraphnet\lib\site-packages\tensorflow_core\python\training\training_util.py:236: Variable.initialized_value (from tensorflow.python.ops.variables) is deprecated and will be removed in a future version.
# Instructions for updating:
# Use Variable.read_value. Variables in 2.X are initialized automatically both in eager and graph (inside tf.defun) contexts.
# 2022-04-09 08:54:37.921562: W tensorflow/stream_executor/platform/default/dso_loader.cc:55] Could not load dynamic library 'nvcuda.dll'; dlerror: nvcuda.dll not found
# 2022-04-09 08:54:37.921762: E tensorflow/stream_executor/cuda/cuda_driver.cc:318] failed call to cuInit: UNKNOWN ERROR (303)
# 2022-04-09 08:54:37.925210: I tensorflow/stream_executor/cuda/cuda_diagnostics.cc:169] retrieving CUDA diagnostic information for host: DESKTOP-G86FQHS
# 2022-04-09 08:54:37.925450: I tensorflow/stream_executor/cuda/cuda_diagnostics.cc:176] hostname: DESKTOP-G86FQHS
# 2022-04-09 08:54:37.925795: I tensorflow/core/platform/cpu_feature_guard.cc:142] Your CPU supports instructions that this TensorFlow binary was not compiled to use: AVX2
# WARNING:tensorflow:From C:\ProgramData\Anaconda3\envs\meshgraphnet\lib\site-packages\tensorflow_core\python\training\saver.py:1069: get_checkpoint_mtimes (from tensorflow.python.training.checkpoint_management) is deprecated and will be removed in a future version.
# Instructions for updating:
# Use standard file utilities to get mtimes.
# WARNING:tensorflow:It seems that global step (tf.train.get_global_step) has not been increased. Current value (could be stable): 8000 vs previous value: 8000. You could increase the global step by passing tf.train.get_global_step() to Optimizer.apply_gradients or Optimizer.minimize.
# WARNING:tensorflow:It seems that global step (tf.train.get_global_step) has not been increased. Current value (could be stable): 8000 vs previous value: 8000. You could increase the global step by passing tf.train.get_global_step() to Optimizer.apply_gradients or Optimizer.minimize.
# WARNING:tensorflow:It seems that global step (tf.train.get_global_step) has not been increased. Current value (could be stable): 8000 vs previous value: 8000. You could increase the global step by passing tf.train.get_global_step() to Optimizer.apply_gradients or Optimizer.minimize.
# Error List: [3.0677083e-07, 7.413504e-07, 8.422822e-07, 2.9787756e-07]
# 2022-04-09 08:54:39.665621: W tensorflow/stream_executor/platform/default/dso_loader.cc:55] Could not load dynamic library 'cudart64_100.dll'; dlerror: cudart64_100.dll not found
# 2022-04-09 08:54:39.665882: I tensorflow/stream_executor/cuda/cudart_stub.cc:29] Ignore above cudart dlerror if you do not have a GPU set up on your machine.
# WARNING:tensorflow:From C:\ProgramData\Anaconda3\envs\meshgraphnet\lib\site-packages\tensorflow_core\python\ops\resource_variable_ops.py:1630: calling BaseResourceVariable.__init__ (from tensorflow.python.ops.resource_variable_ops) with constraint is deprecated and will be removed in a future version.
# Instructions for updating:
# If using Keras pass *_constraint arguments to layers.
# WARNING:tensorflow:From c:\Temp\HybridML\meshgraphnets\normalization.py:73: where (from tensorflow.python.ops.array_ops) is deprecated and will be removed in a future version.
# Instructions for updating:
# Use tf.where in 2.0, which has the same broadcast rule as np.where
# WARNING:tensorflow:From C:\ProgramData\Anaconda3\envs\meshgraphnet\lib\site-packages\sonnet\python\modules\basic.py:127: calling TruncatedNormal.__init__ (from tensorflow.python.ops.init_ops) with dtype is deprecated and will be removed in a future version.
# Instructions for updating:
# Call initializer instance with the dtype argument instead of passing it to the constructor
# WARNING:tensorflow:From C:\ProgramData\Anaconda3\envs\meshgraphnet\lib\site-packages\sonnet\python\modules\basic.py:132: calling Zeros.__init__ (from tensorflow.python.ops.init_ops) with dtype is deprecated and will be removed in a future version.
# Instructions for updating:
# Call initializer instance with the dtype argument instead of passing it to the constructor
# WARNING:tensorflow:From C:\ProgramData\Anaconda3\envs\meshgraphnet\lib\site-packages\tensorflow_core\python\training\training_util.py:236: Variable.initialized_value (from tensorflow.python.ops.variables) is deprecated and will be removed in a future version.
# Instructions for updating:
# Use Variable.read_value. Variables in 2.X are initialized automatically both in eager and graph (inside tf.defun) contexts.
# 2022-04-09 08:54:44.837912: W tensorflow/stream_executor/platform/default/dso_loader.cc:55] Could not load dynamic library 'nvcuda.dll'; dlerror: nvcuda.dll not found
# 2022-04-09 08:54:44.838085: E tensorflow/stream_executor/cuda/cuda_driver.cc:318] failed call to cuInit: UNKNOWN ERROR (303)
# 2022-04-09 08:54:44.841366: I tensorflow/stream_executor/cuda/cuda_diagnostics.cc:169] retrieving CUDA diagnostic information for host: DESKTOP-G86FQHS
# 2022-04-09 08:54:44.841623: I tensorflow/stream_executor/cuda/cuda_diagnostics.cc:176] hostname: DESKTOP-G86FQHS
# 2022-04-09 08:54:44.841895: I tensorflow/core/platform/cpu_feature_guard.cc:142] Your CPU supports instructions that this TensorFlow binary was not compiled to use: AVX2
# WARNING:tensorflow:From C:\ProgramData\Anaconda3\envs\meshgraphnet\lib\site-packages\tensorflow_core\python\training\saver.py:1069: get_checkpoint_mtimes (from tensorflow.python.training.checkpoint_management) is deprecated and will be removed in a future version.
# Instructions for updating:
# Use standard file utilities to get mtimes.
# WARNING:tensorflow:It seems that global step (tf.train.get_global_step) has not been increased. Current value (could be stable): 8000 vs previous value: 8000. You could increase the global step by passing tf.train.get_global_step() to Optimizer.apply_gradients or Optimizer.minimize.
# WARNING:tensorflow:It seems that global step (tf.train.get_global_step) has not been increased. Current value (could be stable): 8000 vs previous value: 8000. You could increase the global step by passing tf.train.get_global_step() to Optimizer.apply_gradients or Optimizer.minimize.
# WARNING:tensorflow:It seems that global step (tf.train.get_global_step) has not been increased. Current value (could be stable): 8000 vs previous value: 8000. You could increase the global step by passing tf.train.get_global_step() to Optimizer.apply_gradients or Optimizer.minimize.
# WARNING:tensorflow:It seems that global step (tf.train.get_global_step) has not been increased. Current value (could be stable): 8000 vs previous value: 8000. You could increase the global step by passing tf.train.get_global_step() to Optimizer.apply_gradients or Optimizer.minimize.
# WARNING:tensorflow:It seems that global step (tf.train.get_global_step) has not been increased. Current value (could be stable): 8000 vs previous value: 8000. You could increase the global step by passing tf.train.get_global_step() to Optimizer.apply_gradients or Optimizer.minimize.
# Error List: [0.000478875, 0.00096039573, 0.00061454205, 0.0003645907, 0.00027865492, 0.00025770417, 0.00206317, 0.0013097589, 0.00067298487, 0.002405203]
# 2022-04-09 08:54:46.748389: W tensorflow/stream_executor/platform/default/dso_loader.cc:55] Could not load dynamic library 'cudart64_100.dll'; dlerror: cudart64_100.dll not found
# 2022-04-09 08:54:46.748637: I tensorflow/stream_executor/cuda/cudart_stub.cc:29] Ignore above cudart dlerror if you do not have a GPU set up on your machine.
# WARNING:tensorflow:From C:\ProgramData\Anaconda3\envs\meshgraphnet\lib\site-packages\tensorflow_core\python\ops\resource_variable_ops.py:1630: calling BaseResourceVariable.__init__ (from tensorflow.python.ops.resource_variable_ops) with constraint is deprecated and will be removed in a future version.
# Instructions for updating:
# If using Keras pass *_constraint arguments to layers.
# WARNING:tensorflow:From c:\Temp\HybridML\meshgraphnets\normalization.py:73: where (from tensorflow.python.ops.array_ops) is deprecated and will be removed in a future version.
# Instructions for updating:
# Use tf.where in 2.0, which has the same broadcast rule as np.where
# WARNING:tensorflow:From C:\ProgramData\Anaconda3\envs\meshgraphnet\lib\site-packages\sonnet\python\modules\basic.py:127: calling TruncatedNormal.__init__ (from tensorflow.python.ops.init_ops) with dtype is deprecated and will be removed in a future version.
# Instructions for updating:
# Call initializer instance with the dtype argument instead of passing it to the constructor
# WARNING:tensorflow:From C:\ProgramData\Anaconda3\envs\meshgraphnet\lib\site-packages\sonnet\python\modules\basic.py:132: calling Zeros.__init__ (from tensorflow.python.ops.init_ops) with dtype is deprecated and will be removed in a future version.
# Instructions for updating:
# Call initializer instance with the dtype argument instead of passing it to the constructor
# WARNING:tensorflow:From C:\ProgramData\Anaconda3\envs\meshgraphnet\lib\site-packages\tensorflow_core\python\training\training_util.py:236: Variable.initialized_value (from tensorflow.python.ops.variables) is deprecated and will be removed in a future version.
# Instructions for updating:
# Use Variable.read_value. Variables in 2.X are initialized automatically both in eager and graph (inside tf.defun) contexts.
# 2022-04-09 08:54:51.904919: W tensorflow/stream_executor/platform/default/dso_loader.cc:55] Could not load dynamic library 'nvcuda.dll'; dlerror: nvcuda.dll not found
# 2022-04-09 08:54:51.905106: E tensorflow/stream_executor/cuda/cuda_driver.cc:318] failed call to cuInit: UNKNOWN ERROR (303)
# 2022-04-09 08:54:51.908435: I tensorflow/stream_executor/cuda/cuda_diagnostics.cc:169] retrieving CUDA diagnostic information for host: DESKTOP-G86FQHS
# 2022-04-09 08:54:51.908670: I tensorflow/stream_executor/cuda/cuda_diagnostics.cc:176] hostname: DESKTOP-G86FQHS
# 2022-04-09 08:54:51.908999: I tensorflow/core/platform/cpu_feature_guard.cc:142] Your CPU supports instructions that this TensorFlow binary was not compiled to use: AVX2
# WARNING:tensorflow:From C:\ProgramData\Anaconda3\envs\meshgraphnet\lib\site-packages\tensorflow_core\python\training\saver.py:1069: get_checkpoint_mtimes (from tensorflow.python.training.checkpoint_management) is deprecated and will be removed in a future version.
# Instructions for updating:
# Use standard file utilities to get mtimes.
# WARNING:tensorflow:It seems that global step (tf.train.get_global_step) has not been increased. Current value (could be stable): 8000 vs previous value: 8000. You could increase the global step by passing tf.train.get_global_step() to Optimizer.apply_gradients or Optimizer.minimize.
# WARNING:tensorflow:It seems that global step (tf.train.get_global_step) has not been increased. Current value (could be stable): 8000 vs previous value: 8000. You could increase the global step by passing tf.train.get_global_step() to Optimizer.apply_gradients or Optimizer.minimize.
# WARNING:tensorflow:It seems that global step (tf.train.get_global_step) has not been increased. Current value (could be stable): 8000 vs previous value: 8000. You could increase the global step by passing tf.train.get_global_step() to Optimizer.apply_gradients or Optimizer.minimize.
# WARNING:tensorflow:It seems that global step (tf.train.get_global_step) has not been increased. Current value (could be stable): 8000 vs previous value: 8000. You could increase the global step by passing tf.train.get_global_step() to Optimizer.apply_gradients or Optimizer.minimize.
# WARNING:tensorflow:It seems that global step (tf.train.get_global_step) has not been increased. Current value (could be stable): 8000 vs previous value: 8000. You could increase the global step by passing tf.train.get_global_step() to Optimizer.apply_gradients or Optimizer.minimize.
# Error List: [0.00021706572, 0.00014056441, 0.0008977521, 0.00011197848, 0.0008733572, 0.00044959423, 0.0003086724, 0.00025504275, 0.0002597321, 0.0003828139]
# 2022-04-09 08:54:53.790842: W tensorflow/stream_executor/platform/default/dso_loader.cc:55] Could not load dynamic library 'cudart64_100.dll'; dlerror: cudart64_100.dll not found
# 2022-04-09 08:54:53.791115: I tensorflow/stream_executor/cuda/cudart_stub.cc:29] Ignore above cudart dlerror if you do not have a GPU set up on your machine.
# WARNING:tensorflow:From C:\ProgramData\Anaconda3\envs\meshgraphnet\lib\site-packages\tensorflow_core\python\ops\resource_variable_ops.py:1630: calling BaseResourceVariable.__init__ (from tensorflow.python.ops.resource_variable_ops) with constraint is deprecated and will be removed in a future version.
# Instructions for updating:
# If using Keras pass *_constraint arguments to layers.
# WARNING:tensorflow:From c:\Temp\HybridML\meshgraphnets\normalization.py:73: where (from tensorflow.python.ops.array_ops) is deprecated and will be removed in a future version.
# Instructions for updating:
# Use tf.where in 2.0, which has the same broadcast rule as np.where
# WARNING:tensorflow:From C:\ProgramData\Anaconda3\envs\meshgraphnet\lib\site-packages\sonnet\python\modules\basic.py:127: calling TruncatedNormal.__init__ (from tensorflow.python.ops.init_ops) with dtype is deprecated and will be removed in a future version.
# Instructions for updating:
# Call initializer instance with the dtype argument instead of passing it to the constructor
# WARNING:tensorflow:From C:\ProgramData\Anaconda3\envs\meshgraphnet\lib\site-packages\sonnet\python\modules\basic.py:132: calling Zeros.__init__ (from tensorflow.python.ops.init_ops) with dtype is deprecated and will be removed in a future version.
# Instructions for updating:
# Call initializer instance with the dtype argument instead of passing it to the constructor
# WARNING:tensorflow:From C:\ProgramData\Anaconda3\envs\meshgraphnet\lib\site-packages\tensorflow_core\python\training\training_util.py:236: Variable.initialized_value (from tensorflow.python.ops.variables) is deprecated and will be removed in a future version.
# Instructions for updating:
# Use Variable.read_value. Variables in 2.X are initialized automatically both in eager and graph (inside tf.defun) contexts.
# 2022-04-09 08:54:58.981199: W tensorflow/stream_executor/platform/default/dso_loader.cc:55] Could not load dynamic library 'nvcuda.dll'; dlerror: nvcuda.dll not found
# 2022-04-09 08:54:58.981368: E tensorflow/stream_executor/cuda/cuda_driver.cc:318] failed call to cuInit: UNKNOWN ERROR (303)
# 2022-04-09 08:54:58.984482: I tensorflow/stream_executor/cuda/cuda_diagnostics.cc:169] retrieving CUDA diagnostic information for host: DESKTOP-G86FQHS
# 2022-04-09 08:54:58.984695: I tensorflow/stream_executor/cuda/cuda_diagnostics.cc:176] hostname: DESKTOP-G86FQHS
# 2022-04-09 08:54:58.985020: I tensorflow/core/platform/cpu_feature_guard.cc:142] Your CPU supports instructions that this TensorFlow binary was not compiled to use: AVX2
# WARNING:tensorflow:From C:\ProgramData\Anaconda3\envs\meshgraphnet\lib\site-packages\tensorflow_core\python\training\saver.py:1069: get_checkpoint_mtimes (from tensorflow.python.training.checkpoint_management) is deprecated and will be removed in a future version.
# Instructions for updating:
# Use standard file utilities to get mtimes.
# WARNING:tensorflow:It seems that global step (tf.train.get_global_step) has not been increased. Current value (could be stable): 8000 vs previous value: 8000. You could increase the global step by passing tf.train.get_global_step() to Optimizer.apply_gradients or Optimizer.minimize.
# WARNING:tensorflow:It seems that global step (tf.train.get_global_step) has not been increased. Current value (could be stable): 8000 vs previous value: 8000. You could increase the global step by passing tf.train.get_global_step() to Optimizer.apply_gradients or Optimizer.minimize.
# WARNING:tensorflow:It seems that global step (tf.train.get_global_step) has not been increased. Current value (could be stable): 8000 vs previous value: 8000. You could increase the global step by passing tf.train.get_global_step() to Optimizer.apply_gradients or Optimizer.minimize.
# WARNING:tensorflow:It seems that global step (tf.train.get_global_step) has not been increased. Current value (could be stable): 8000 vs previous value: 8000. You could increase the global step by passing tf.train.get_global_step() to Optimizer.apply_gradients or Optimizer.minimize.
# WARNING:tensorflow:It seems that global step (tf.train.get_global_step) has not been increased. Current value (could be stable): 8000 vs previous value: 8000. You could increase the global step by passing tf.train.get_global_step() to Optimizer.apply_gradients or Optimizer.minimize.
# Error List: [0.00019574896, 0.00020445474, 0.00065793993, 0.00010700585, 0.00038401803, 0.00029656428, 0.00042447593, 0.000490589, 0.00016898986, 0.00023716134]
# 2022-04-09 08:55:00.835728: W tensorflow/stream_executor/platform/default/dso_loader.cc:55] Could not load dynamic library 'cudart64_100.dll'; dlerror: cudart64_100.dll not found
# 2022-04-09 08:55:00.835990: I tensorflow/stream_executor/cuda/cudart_stub.cc:29] Ignore above cudart dlerror if you do not have a GPU set up on your machine.
# WARNING:tensorflow:From C:\ProgramData\Anaconda3\envs\meshgraphnet\lib\site-packages\tensorflow_core\python\ops\resource_variable_ops.py:1630: calling BaseResourceVariable.__init__ (from tensorflow.python.ops.resource_variable_ops) with constraint is deprecated and will be removed in a future version.
# Instructions for updating:
# If using Keras pass *_constraint arguments to layers.
# WARNING:tensorflow:From c:\Temp\HybridML\meshgraphnets\normalization.py:73: where (from tensorflow.python.ops.array_ops) is deprecated and will be removed in a future version.
# Instructions for updating:
# Use tf.where in 2.0, which has the same broadcast rule as np.where
# WARNING:tensorflow:From C:\ProgramData\Anaconda3\envs\meshgraphnet\lib\site-packages\sonnet\python\modules\basic.py:127: calling TruncatedNormal.__init__ (from tensorflow.python.ops.init_ops) with dtype is deprecated and will be removed in a future version.
# Instructions for updating:
# Call initializer instance with the dtype argument instead of passing it to the constructor
# WARNING:tensorflow:From C:\ProgramData\Anaconda3\envs\meshgraphnet\lib\site-packages\sonnet\python\modules\basic.py:132: calling Zeros.__init__ (from tensorflow.python.ops.init_ops) with dtype is deprecated and will be removed in a future version.
# Instructions for updating:
# Call initializer instance with the dtype argument instead of passing it to the constructor
# WARNING:tensorflow:From C:\ProgramData\Anaconda3\envs\meshgraphnet\lib\site-packages\tensorflow_core\python\training\training_util.py:236: Variable.initialized_value (from tensorflow.python.ops.variables) is deprecated and will be removed in a future version.
# Instructions for updating:
# Use Variable.read_value. Variables in 2.X are initialized automatically both in eager and graph (inside tf.defun) contexts.
# 2022-04-09 08:55:05.880424: W tensorflow/stream_executor/platform/default/dso_loader.cc:55] Could not load dynamic library 'nvcuda.dll'; dlerror: nvcuda.dll not found
# 2022-04-09 08:55:05.880601: E tensorflow/stream_executor/cuda/cuda_driver.cc:318] failed call to cuInit: UNKNOWN ERROR (303)
# 2022-04-09 08:55:05.883489: I tensorflow/stream_executor/cuda/cuda_diagnostics.cc:169] retrieving CUDA diagnostic information for host: DESKTOP-G86FQHS
# 2022-04-09 08:55:05.883677: I tensorflow/stream_executor/cuda/cuda_diagnostics.cc:176] hostname: DESKTOP-G86FQHS
# 2022-04-09 08:55:05.884038: I tensorflow/core/platform/cpu_feature_guard.cc:142] Your CPU supports instructions that this TensorFlow binary was not compiled to use: AVX2
# WARNING:tensorflow:From C:\ProgramData\Anaconda3\envs\meshgraphnet\lib\site-packages\tensorflow_core\python\training\saver.py:1069: get_checkpoint_mtimes (from tensorflow.python.training.checkpoint_management) is deprecated and will be removed in a future version.
# Instructions for updating:
# Use standard file utilities to get mtimes.
# WARNING:tensorflow:It seems that global step (tf.train.get_global_step) has not been increased. Current value (could be stable): 8000 vs previous value: 8000. You could increase the global step by passing tf.train.get_global_step() to Optimizer.apply_gradients or Optimizer.minimize.
# WARNING:tensorflow:It seems that global step (tf.train.get_global_step) has not been increased. Current value (could be stable): 8000 vs previous value: 8000. You could increase the global step by passing tf.train.get_global_step() to Optimizer.apply_gradients or Optimizer.minimize.
# WARNING:tensorflow:It seems that global step (tf.train.get_global_step) has not been increased. Current value (could be stable): 8000 vs previous value: 8000. You could increase the global step by passing tf.train.get_global_step() to Optimizer.apply_gradients or Optimizer.minimize.
# WARNING:tensorflow:It seems that global step (tf.train.get_global_step) has not been increased. Current value (could be stable): 8000 vs previous value: 8000. You could increase the global step by passing tf.train.get_global_step() to Optimizer.apply_gradients or Optimizer.minimize.
# WARNING:tensorflow:It seems that global step (tf.train.get_global_step) has not been increased. Current value (could be stable): 8000 vs previous value: 8000. You could increase the global step by passing tf.train.get_global_step() to Optimizer.apply_gradients or Optimizer.minimize.
# ...
# Use standard file utilities to get mtimes.
# WARNING:tensorflow:It seems that global step (tf.train.get_global_step) has not been increased. Current value (could be stable): 8000 vs previous value: 8000. You could increase the global step by passing tf.train.get_global_step() to Optimizer.apply_gradients or Optimizer.minimize.
# WARNING:tensorflow:It seems that global step (tf.train.get_global_step) has not been increased. Current value (could be stable): 8000 vs previous value: 8000. You could increase the global step by passing tf.train.get_global_step() to Optimizer.apply_gradients or Optimizer.minimize.
# WARNING:tensorflow:It seems that global step (tf.train.get_global_step) has not been increased. Current value (could be stable): 8000 vs previous value: 8000. You could increase the global step by passing tf.train.get_global_step() to Optimizer.apply_gradients or Optimizer.minimize.
# WARNING:tensorflow:It seems that global step (tf.train.get_global_step) has not been increased. Current value (could be stable): 8000 vs previous value: 8000. You could increase the global step by passing tf.train.get_global_step() to Optimizer.apply_gradients or Optimizer.minimize.
# WARNING:tensorflow:It seems that global step (tf.train.get_global_step) has not been increased. Current value (could be stable): 8000 vs previous value: 8000. You could increase the global step by passing tf.train.get_global_step() to Optimizer.apply_gradients or Optimizer.minimize.
# Error List: [0.00010156074, 6.514282e-05, 4.5085504e-05, 7.0892374e-06, 3.275349e-05, 3.2281816e-05, 0.00015525332, 5.0500526e-05, 3.4536497e-05, 7.717303e-05]
# 2022-04-09 10:46:12.325189: W tensorflow/stream_executor/platform/default/dso_loader.cc:55] Could not load dynamic library 'cudart64_100.dll'; dlerror: cudart64_100.dll not found
# 2022-04-09 10:46:12.325447: I tensorflow/stream_executor/cuda/cudart_stub.cc:29] Ignore above cudart dlerror if you do not have a GPU set up on your machine.
# WARNING:tensorflow:From C:\ProgramData\Anaconda3\envs\meshgraphnet\lib\site-packages\tensorflow_core\python\ops\resource_variable_ops.py:1630: calling BaseResourceVariable.__init__ (from tensorflow.python.ops.resource_variable_ops) with constraint is deprecated and will be removed in a future version.
# Instructions for updating:
# If using Keras pass *_constraint arguments to layers.
# WARNING:tensorflow:From c:\Temp\HybridML\meshgraphnets\normalization.py:73: where (from tensorflow.python.ops.array_ops) is deprecated and will be removed in a future version.
# Instructions for updating:
# Use tf.where in 2.0, which has the same broadcast rule as np.where
# WARNING:tensorflow:From C:\ProgramData\Anaconda3\envs\meshgraphnet\lib\site-packages\sonnet\python\modules\basic.py:127: calling TruncatedNormal.__init__ (from tensorflow.python.ops.init_ops) with dtype is deprecated and will be removed in a future version.
# Instructions for updating:
# Call initializer instance with the dtype argument instead of passing it to the constructor
# WARNING:tensorflow:From C:\ProgramData\Anaconda3\envs\meshgraphnet\lib\site-packages\sonnet\python\modules\basic.py:132: calling Zeros.__init__ (from tensorflow.python.ops.init_ops) with dtype is deprecated and will be removed in a future version.
# Instructions for updating:
# Call initializer instance with the dtype argument instead of passing it to the constructor
# WARNING:tensorflow:From C:\ProgramData\Anaconda3\envs\meshgraphnet\lib\site-packages\tensorflow_core\python\training\training_util.py:236: Variable.initialized_value (from tensorflow.python.ops.variables) is deprecated and will be removed in a future version.
# Instructions for updating:
# Use Variable.read_value. Variables in 2.X are initialized automatically both in eager and graph (inside tf.defun) contexts.
# 2022-04-09 10:46:17.701138: W tensorflow/stream_executor/platform/default/dso_loader.cc:55] Could not load dynamic library 'nvcuda.dll'; dlerror: nvcuda.dll not found
# 2022-04-09 10:46:17.701306: E tensorflow/stream_executor/cuda/cuda_driver.cc:318] failed call to cuInit: UNKNOWN ERROR (303)
# 2022-04-09 10:46:17.704258: I tensorflow/stream_executor/cuda/cuda_diagnostics.cc:169] retrieving CUDA diagnostic information for host: DESKTOP-G86FQHS
# 2022-04-09 10:46:17.704428: I tensorflow/stream_executor/cuda/cuda_diagnostics.cc:176] hostname: DESKTOP-G86FQHS
# 2022-04-09 10:46:17.704847: I tensorflow/core/platform/cpu_feature_guard.cc:142] Your CPU supports instructions that this TensorFlow binary was not compiled to use: AVX2
# WARNING:tensorflow:From C:\ProgramData\Anaconda3\envs\meshgraphnet\lib\site-packages\tensorflow_core\python\training\saver.py:1069: get_checkpoint_mtimes (from tensorflow.python.training.checkpoint_management) is deprecated and will be removed in a future version.
# Instructions for updating:
# Use standard file utilities to get mtimes.
# WARNING:tensorflow:It seems that global step (tf.train.get_global_step) has not been increased. Current value (could be stable): 8000 vs previous value: 8000. You could increase the global step by passing tf.train.get_global_step() to Optimizer.apply_gradients or Optimizer.minimize.
# WARNING:tensorflow:It seems that global step (tf.train.get_global_step) has not been increased. Current value (could be stable): 8000 vs previous value: 8000. You could increase the global step by passing tf.train.get_global_step() to Optimizer.apply_gradients or Optimizer.minimize.
# WARNING:tensorflow:It seems that global step (tf.train.get_global_step) has not been increased. Current value (could be stable): 8000 vs previous value: 8000. You could increase the global step by passing tf.train.get_global_step() to Optimizer.apply_gradients or Optimizer.minimize.
# WARNING:tensorflow:It seems that global step (tf.train.get_global_step) has not been increased. Current value (could be stable): 8000 vs previous value: 8000. You could increase the global step by passing tf.train.get_global_step() to Optimizer.apply_gradients or Optimizer.minimize.
# WARNING:tensorflow:It seems that global step (tf.train.get_global_step) has not been increased. Current value (could be stable): 8000 vs previous value: 8000. You could increase the global step by passing tf.train.get_global_step() to Optimizer.apply_gradients or Optimizer.minimize.
# Error List: [0.0005589664, 0.0015595084, 0.00068972155, 0.00026410221, 0.0012045032, 0.0009025766, 0.0018423576, 0.0004672011, 0.0010552831, 9.339173e-05]
# 2022-04-09 10:46:19.512338: W tensorflow/stream_executor/platform/default/dso_loader.cc:55] Could not load dynamic library 'cudart64_100.dll'; dlerror: cudart64_100.dll not found
# 2022-04-09 10:46:19.512524: I tensorflow/stream_executor/cuda/cudart_stub.cc:29] Ignore above cudart dlerror if you do not have a GPU set up on your machine.
# WARNING:tensorflow:From C:\ProgramData\Anaconda3\envs\meshgraphnet\lib\site-packages\tensorflow_core\python\ops\resource_variable_ops.py:1630: calling BaseResourceVariable.__init__ (from tensorflow.python.ops.resource_variable_ops) with constraint is deprecated and will be removed in a future version.
# Instructions for updating:
# If using Keras pass *_constraint arguments to layers.
# WARNING:tensorflow:From c:\Temp\HybridML\meshgraphnets\normalization.py:73: where (from tensorflow.python.ops.array_ops) is deprecated and will be removed in a future version.
# Instructions for updating:
# Use tf.where in 2.0, which has the same broadcast rule as np.where
# WARNING:tensorflow:From C:\ProgramData\Anaconda3\envs\meshgraphnet\lib\site-packages\sonnet\python\modules\basic.py:127: calling TruncatedNormal.__init__ (from tensorflow.python.ops.init_ops) with dtype is deprecated and will be removed in a future version.
# Instructions for updating:
# Call initializer instance with the dtype argument instead of passing it to the constructor
# WARNING:tensorflow:From C:\ProgramData\Anaconda3\envs\meshgraphnet\lib\site-packages\sonnet\python\modules\basic.py:132: calling Zeros.__init__ (from tensorflow.python.ops.init_ops) with dtype is deprecated and will be removed in a future version.
# Instructions for updating:
# Call initializer instance with the dtype argument instead of passing it to the constructor
# WARNING:tensorflow:From C:\ProgramData\Anaconda3\envs\meshgraphnet\lib\site-packages\tensorflow_core\python\training\training_util.py:236: Variable.initialized_value (from tensorflow.python.ops.variables) is deprecated and will be removed in a future version.
# Instructions for updating:
# Use Variable.read_value. Variables in 2.X are initialized automatically both in eager and graph (inside tf.defun) contexts.
# 2022-04-09 10:46:24.749225: W tensorflow/stream_executor/platform/default/dso_loader.cc:55] Could not load dynamic library 'nvcuda.dll'; dlerror: nvcuda.dll not found
# 2022-04-09 10:46:24.749408: E tensorflow/stream_executor/cuda/cuda_driver.cc:318] failed call to cuInit: UNKNOWN ERROR (303)
# 2022-04-09 10:46:24.752848: I tensorflow/stream_executor/cuda/cuda_diagnostics.cc:169] retrieving CUDA diagnostic information for host: DESKTOP-G86FQHS
# 2022-04-09 10:46:24.753062: I tensorflow/stream_executor/cuda/cuda_diagnostics.cc:176] hostname: DESKTOP-G86FQHS
# 2022-04-09 10:46:24.753375: I tensorflow/core/platform/cpu_feature_guard.cc:142] Your CPU supports instructions that this TensorFlow binary was not compiled to use: AVX2
# WARNING:tensorflow:From C:\ProgramData\Anaconda3\envs\meshgraphnet\lib\site-packages\tensorflow_core\python\training\saver.py:1069: get_checkpoint_mtimes (from tensorflow.python.training.checkpoint_management) is deprecated and will be removed in a future version.
# Instructions for updating:
# Use standard file utilities to get mtimes.
# WARNING:tensorflow:It seems that global step (tf.train.get_global_step) has not been increased. Current value (could be stable): 8000 vs previous value: 8000. You could increase the global step by passing tf.train.get_global_step() to Optimizer.apply_gradients or Optimizer.minimize.
# WARNING:tensorflow:It seems that global step (tf.train.get_global_step) has not been increased. Current value (could be stable): 8000 vs previous value: 8000. You could increase the global step by passing tf.train.get_global_step() to Optimizer.apply_gradients or Optimizer.minimize.
# WARNING:tensorflow:It seems that global step (tf.train.get_global_step) has not been increased. Current value (could be stable): 8000 vs previous value: 8000. You could increase the global step by passing tf.train.get_global_step() to Optimizer.apply_gradients or Optimizer.minimize.
# WARNING:tensorflow:It seems that global step (tf.train.get_global_step) has not been increased. Current value (could be stable): 8000 vs previous value: 8000. You could increase the global step by passing tf.train.get_global_step() to Optimizer.apply_gradients or Optimizer.minimize.
# WARNING:tensorflow:It seems that global step (tf.train.get_global_step) has not been increased. Current value (could be stable): 8000 vs previous value: 8000. You could increase the global step by passing tf.train.get_global_step() to Optimizer.apply_gradients or Optimizer.minimize.
# Error List: [8.9621135e-05, 0.0002482344, 2.7202974e-05, 4.5135013e-05, 4.98616e-05, 3.9999763e-05, 0.00016307569, 0.00016750743, 0.00012283097, 2.4355388e-05]
# 2022-04-09 10:46:26.573670: W tensorflow/stream_executor/platform/default/dso_loader.cc:55] Could not load dynamic library 'cudart64_100.dll'; dlerror: cudart64_100.dll not found
# 2022-04-09 10:46:26.573833: I tensorflow/stream_executor/cuda/cudart_stub.cc:29] Ignore above cudart dlerror if you do not have a GPU set up on your machine.
# WARNING:tensorflow:From C:\ProgramData\Anaconda3\envs\meshgraphnet\lib\site-packages\tensorflow_core\python\ops\resource_variable_ops.py:1630: calling BaseResourceVariable.__init__ (from tensorflow.python.ops.resource_variable_ops) with constraint is deprecated and will be removed in a future version.
# Instructions for updating:
# If using Keras pass *_constraint arguments to layers.
# WARNING:tensorflow:From c:\Temp\HybridML\meshgraphnets\normalization.py:73: where (from tensorflow.python.ops.array_ops) is deprecated and will be removed in a future version.
# Instructions for updating:
# Use tf.where in 2.0, which has the same broadcast rule as np.where
# WARNING:tensorflow:From C:\ProgramData\Anaconda3\envs\meshgraphnet\lib\site-packages\sonnet\python\modules\basic.py:127: calling TruncatedNormal.__init__ (from tensorflow.python.ops.init_ops) with dtype is deprecated and will be removed in a future version.
# Instructions for updating:
# Call initializer instance with the dtype argument instead of passing it to the constructor
# WARNING:tensorflow:From C:\ProgramData\Anaconda3\envs\meshgraphnet\lib\site-packages\sonnet\python\modules\basic.py:132: calling Zeros.__init__ (from tensorflow.python.ops.init_ops) with dtype is deprecated and will be removed in a future version.
# Instructions for updating:
# Call initializer instance with the dtype argument instead of passing it to the constructor
# WARNING:tensorflow:From C:\ProgramData\Anaconda3\envs\meshgraphnet\lib\site-packages\tensorflow_core\python\training\training_util.py:236: Variable.initialized_value (from tensorflow.python.ops.variables) is deprecated and will be removed in a future version.
# Instructions for updating:
# Use Variable.read_value. Variables in 2.X are initialized automatically both in eager and graph (inside tf.defun) contexts.
# 2022-04-09 10:46:31.951277: W tensorflow/stream_executor/platform/default/dso_loader.cc:55] Could not load dynamic library 'nvcuda.dll'; dlerror: nvcuda.dll not found
# 2022-04-09 10:46:31.951515: E tensorflow/stream_executor/cuda/cuda_driver.cc:318] failed call to cuInit: UNKNOWN ERROR (303)
# 2022-04-09 10:46:31.955336: I tensorflow/stream_executor/cuda/cuda_diagnostics.cc:169] retrieving CUDA diagnostic information for host: DESKTOP-G86FQHS
# 2022-04-09 10:46:31.955561: I tensorflow/stream_executor/cuda/cuda_diagnostics.cc:176] hostname: DESKTOP-G86FQHS
# 2022-04-09 10:46:31.955919: I tensorflow/core/platform/cpu_feature_guard.cc:142] Your CPU supports instructions that this TensorFlow binary was not compiled to use: AVX2
# WARNING:tensorflow:From C:\ProgramData\Anaconda3\envs\meshgraphnet\lib\site-packages\tensorflow_core\python\training\saver.py:1069: get_checkpoint_mtimes (from tensorflow.python.training.checkpoint_management) is deprecated and will be removed in a future version.
# Instructions for updating:
# Use standard file utilities to get mtimes.
# WARNING:tensorflow:It seems that global step (tf.train.get_global_step) has not been increased. Current value (could be stable): 8000 vs previous value: 8000. You could increase the global step by passing tf.train.get_global_step() to Optimizer.apply_gradients or Optimizer.minimize.
# WARNING:tensorflow:It seems that global step (tf.train.get_global_step) has not been increased. Current value (could be stable): 8000 vs previous value: 8000. You could increase the global step by passing tf.train.get_global_step() to Optimizer.apply_gradients or Optimizer.minimize.
# WARNING:tensorflow:It seems that global step (tf.train.get_global_step) has not been increased. Current value (could be stable): 8000 vs previous value: 8000. You could increase the global step by passing tf.train.get_global_step() to Optimizer.apply_gradients or Optimizer.minimize.
# WARNING:tensorflow:It seems that global step (tf.train.get_global_step) has not been increased. Current value (could be stable): 8000 vs previous value: 8000. You could increase the global step by passing tf.train.get_global_step() to Optimizer.apply_gradients or Optimizer.minimize.
# WARNING:tensorflow:It seems that global step (tf.train.get_global_step) has not been increased. Current value (could be stable): 8000 vs previous value: 8000. You could increase the global step by passing tf.train.get_global_step() to Optimizer.apply_gradients or Optimizer.minimize.
# Error List: [0.000114843046, 0.0002501217, 8.6405336e-05, 3.5664634e-05, 0.00011894041, 8.457712e-05, 0.00013917846, 0.00017580473, 0.0001867012, 1.8439063e-05]

# %%
# Loading and combining the the evaluations metrics for each 2D surrogate
# and saving them into a new dictionary that is more simpler for the
# subsequent data visualization.
data_name_list = ["data_2d_1", "data_2d_2"]

table = {}
for data_name in data_name_list:
    table[data_name] = {}
    with open(data_name, 'rb') as f: data = pickle.load(f)
    
    for experiment_id in data.keys():
        checkpoint_folder_list = data[experiment_id]["checkpoint_folder_list"]
        n_initial_steps_list = data[experiment_id]["n_initial_steps_list"]
        n_samples = experiment_id.split("_")[0]
        table[data_name][n_samples] = {}
        for checkpoint_folder in checkpoint_folder_list:
            model_type = checkpoint_folder.split("_")[0]
            table[data_name][n_samples][model_type] = {}
            
            for db_key in ["valid", "test"]:
                fdir=os.path.join("dir", checkpoint_folder, 'evaluation_(%s).npy'%(db_key))
                with open(fdir, 'rb') as f:
                    errorList = np.load(f)
                    targetList = np.load(f)
                    predictionList = np.load(f)
                
                mse = (np.square(targetList[:,0,:,:] - predictionList[:,:,:])).mean()
                table[data_name][n_samples][model_type][db_key] = [mse] # this clarifies its structure

# %%
plt.clf();
fig = plt.figure(figsize=(15, 6))

i = 0
ax = []

x = n_samples_list = [int(key) for key in table[data_name].keys()]
model_list = list(table[data_name][n_samples])

for data_name in data_name_list:
    i += 1
    ax.append(fig.add_subplot(1, 2, i))
    for model in model_list[:2]:
        if model == 'ML model':
            style_type = 'bo'
        elif model == 'HML model':
            style_type = 'ro'
        else:
            style_type = 'yo'
        
        for db_type in ['valid', 'test']:
            if db_type == 'valid':
                style = '-' + style_type
            else:
                style = '--' + style_type
        
            y = []
            for n_sample in n_samples_list:
                y.append(table[data_name][str(n_sample)][model][db_type])
            
            linewidth = 2
            ax[-1].plot(x, y, style, linewidth=linewidth)
            ax[-1].set(xlabel='#Training samples', ylabel='MSE')
    
    ax[-1].set_xticks(x)
    ax[-1].set_ylim(0,13e-4)
    ax[-1].ticklabel_format(useOffset=False)
    ax[-1].set_title('(2D model %s)'%(i), pad=10)

ax[-1].legend(['Validation (ML)', 'Testing (ML)', 'Validation (HML)', 'Testing (HML)'], bbox_to_anchor= (1.62,1))

fig.tight_layout()
fig.subplots_adjust(wspace=0.34 , hspace=0.25)
fig.savefig('2d.pdf', format='pdf', dpi=500)

# %%
def generate_row(k,j):
    return ['%.2f / %.2f'%(table[data_name_list[k]][i][model_list[j]]['valid'][0]*1000,
                table[data_name_list[k]][i][model_list[j]]['test'][0]*1000,)
                    for i in table[data_name]]

a = np.array([generate_row(0,0), generate_row(0,1), generate_row(0,2),
              generate_row(1,0), generate_row(1,1), generate_row(1,2),])

multi_columns = pd.MultiIndex.from_tuples([("#Training samples", "4"),
                                        ("#Training samples", "9"),
                                        ("#Training samples", "14"),
                                        ("#Training samples", "20"),])

multi_index = pd.MultiIndex.from_tuples([("1", "ML"),
                                      ("1", "HML"),
                                      ("1", "HML with HF inputs"),
                                      ("2", "ML"),
                                      ("2", "HML"),
                                      ("2", "HML with HF inputs"),],
                                      names=['Model','Surrogate technique'])


df = pd.DataFrame(a, index = multi_index, columns = multi_columns)
print(df.to_latex())
# Out:
# \begin{tabular}{llllll}
# \toprule
#   &                    & \multicolumn{4}{l}{\#Training samples} \\
#   &                    &                 4 &            9 &           14 &           20 \\
# Model & Surrogate technique &                   &              &              &              \\
# \midrule
# 1 & ML &       0.93 / 0.87 &  0.98 / 0.93 &  0.67 / 0.65 &  0.54 / 0.68 \\
#   & HML &       0.28 / 0.25 &  0.09 / 0.16 &  0.09 / 0.16 &  0.07 / 0.15 \\
#   & HML with HF inputs &       0.33 / 0.26 &  0.10 / 0.16 &  0.07 / 0.13 &  0.06 / 0.12 \\
# 2 & ML &       0.94 / 1.01 &  0.92 / 0.98 &  0.64 / 0.82 &  0.55 / 0.86 \\
#   & HML &       0.39 / 0.32 &  0.15 / 0.24 &  0.11 / 0.18 &  0.07 / 0.10 \\
#   & HML with HF inputs &       0.32 / 0.35 &  0.09 / 0.16 &  0.16 / 0.17 &  0.06 / 0.12 \\
# \bottomrule
# \end{tabular}

# %% [markdown]
# # 3D simulation

# %%
seedNum = 43

def scaler(X_train, X_valid, X_test, scalerObj = False):
    '''standard scaling for the 3d models'''
    if scalerObj:
        X_train = scalerObj.transform(X_train)
    else:
        scalerObj = StandardScaler()
        X_train = scalerObj.fit_transform(X_train)
    X_valid = scalerObj.transform(X_valid)
    X_test = scalerObj.transform(X_test)
    return X_train, X_valid, X_test, scalerObj

def preprocessing(X,
                  Y,
                  NumOutputs,
                  scalerList=False,
                  test_size=0.25,
                  random_state=seedNum):
    
    '''preprocessing the datasets of the 3D models'''
    
    if not scalerList: scalerList = [False] * (NumOutputs + 1)
    
    X_train_full, X_test, y_train_full, y_test = train_test_split(X,
                                                                  Y,
                                                                  test_size=test_size,
                                                                  random_state=random_state)
    X_train, X_valid, y_train, y_valid = train_test_split(X_train_full,
                                                          y_train_full,
                                                          test_size=0.25,
                                                          random_state=random_state)
    
    X_train, X_valid, X_test, scalerList[0] = scaler(X_train,
                                                     X_valid,
                                                     X_test,
                                                     scalerList[0])
    
    for i in range(NumOutputs):
        y_train[:,:,i], y_valid[:,:,i], y_test[:,:,i], scalerList[i+1] = scaler(y_train[:,:,i],
                                                                                y_valid[:,:,i],
                                                                                y_test[:,:,i],
                                                                                scalerList[i+1])
    
    y_train = y_train.reshape(y_train.shape[0], -1)
    y_valid = y_valid.reshape(y_valid.shape[0], -1)
    y_test = y_test.reshape(y_test.shape[0], -1)
    
    return X_train, X_valid, X_test, y_train, y_valid, y_test, scalerList[:]

# %%
# high-fidelity data
inputPath = 'input_3d.csv'
outputPath = 'output_3d_highfidelity.csv'
X = np.loadtxt(inputPath, delimiter=",", dtype='float32')
Y = np.loadtxt(outputPath, delimiter=",", dtype='float32')
NumberOfSamples = 100
NumInputs = dict()
NumInputs['ML'] = X.shape[-1]
NumOutputs = Y.shape[-1]
Y = Y.reshape(NumberOfSamples, -1, NumOutputs)
X = X.reshape(NumberOfSamples, -1)

# low-fidelity data
lfPath='output_3d_lowfidelity.csv'
X_lf = np.loadtxt(lfPath, delimiter=",", dtype='float32')
X_lf = X_lf.reshape(NumberOfSamples,-1,3).reshape(NumberOfSamples,-1)
NumInputs['HML'] = X_lf.shape[-1]

# %%
def train_model(X, Y, epochs, test_size, patience, NumOutputs, num_layers, denominator, lr=1e-5, activation='relu'):
    '''a helper fucntion to denfine the ML model for the 3D simulation
    and to return the metrics data.'''
    
    X_train, X_valid, X_test, y_train, y_valid, y_test, _ = preprocessing(X = X,
                                                                          Y = Y,
                                                                          NumOutputs = NumOutputs,
                                                                          test_size = test_size)
    last_units=y_train.shape[-1]
    units = last_units//denominator
    np.random.seed(seedNum)
    model = models.Sequential()
    
    for i in range(num_layers):
        model.add(BatchNormalization())
        model.add(Dense(units=units, activation=activation))
    
    model.add(Dense(last_units))
    model.compile(loss="mean_squared_error",
                  optimizer=optimizers.Adam(lr))
    early_stopping_cb = callbacks.EarlyStopping(patience=patience,
                                                      restore_best_weights=True)
    history = model.fit(X_train,
                        y_train,
                        epochs=epochs,
                        validation_data=(X_valid, y_valid),
                        callbacks=[early_stopping_cb],
                        verbose=0)
    
    temp = np.square(y_test - model.predict(X_test))
    temp = np.mean(temp, axis=0).reshape(1,-1).reshape(1,-1,NumOutputs)
    pmse = np.average(temp, axis=2)
    
    return {'loss':history.history['loss'], 'val_loss': history.history['val_loss'], 'pmse':pmse}

# %%
# defining the hyperparameters for 3D models 1-4.

epochsList = [100, 100, 1000, 1000]
test_sizeList=[0.96, 0.96, 0.96, 0.80]
patienceList = [100, 100, 100, 100]
num_layersList = [4, 4, 4, 4]
denominatorList = [100, 100, 1000, 100]
lrList=[1e-4, 1e-4, 1e-3, 1e-4]
activationList=['relu', 'elu', 'relu', 'relu']

# %%
# Here, we train the model and extrct the metric data for each 3D surrogate.

result3d = []
for epochs,test_size,patience,num_layers,denominator,lr,activation in zip(epochsList,
                                                                          test_sizeList,
                                                                          patienceList,
                                                                          num_layersList,
                                                                          denominatorList,
                                                                          lrList,
                                                                          activationList):
    result=dict()
    for x, modelType in zip([X, X_lf], ['ML','HML']):
        
        start = time.time()
        result[modelType] = train_model(X = x,
                                        Y = Y,
                                        epochs = epochs,
                                        test_size=test_size,
                                        patience = patience,
                                        NumOutputs = NumOutputs,
                                        num_layers = num_layers,
                                        denominator = denominator,
                                        lr=lr,
                                        activation=activation)
        end = time.time()
        print("Elapsed Time: %.4s (min)"%((end - start)/60))
    result3d.append(result)

with open('data_3d', 'wb') as f: pickle.dump(result3d, f)
# Out:
# WARNING:tensorflow:From C:\ProgramData\Anaconda3\envs\MeshGraphNet\lib\site-packages\tensorflow_core\python\ops\resource_variable_ops.py:1630: calling BaseResourceVariable.__init__ (from tensorflow.python.ops.resource_variable_ops) with constraint is deprecated and will be removed in a future version.
# Instructions for updating:
# If using Keras pass *_constraint arguments to layers.
# Elapsed Time: 0.83 (min)
# Elapsed Time: 0.80 (min)
# Elapsed Time: 0.86 (min)
# Elapsed Time: 0.88 (min)
# Elapsed Time: 0.10 (min)
# Elapsed Time: 0.13 (min)
# Elapsed Time: 9.02 (min)
# Elapsed Time: 5.43 (min)

# %%
# plotting the loss funtions:

with open('data_3d', 'rb') as f: result3d = pickle.load(f)

fig, ax = plt.subplots(2,2,figsize=(15,13))
lst = []
k = 0
m = 0
n = 0
p = 0
for result in result3d:
    p += 1
    for modelType in list(result.keys()):
        k += 1
        if p == 1:
            m, n = 0, 0
        elif p == 2:
            m, n = 0, 1
        elif p == 3:
            m, n = 1, 0
        elif p == 4:
            m, n = 1, 1
        
        temp = []
        if modelType == 'ML':
            style = '--'
        else:
            style = '-'
        ax[m,n].plot(result[modelType]['loss'], 'r' + style, linewidth=2)
        ax[m,n].plot(result[modelType]['val_loss'], 'b' + style, linewidth=2)
    
    ax[m,n].set_ylabel('loss')
    ax[m,n].set_xlabel('epoch')
    ax[m,n].set_yscale('log')
    
    if m == 0 and n == 1:
        ax[m,n].legend(['Training (ML)','Validation (ML)','Training (HML)','Validation (HML)'], bbox_to_anchor= (1.05,1))
    
    ax[m,n].set_title('(3D model %s)'%(p), pad=10)

fig.tight_layout()
fig.subplots_adjust(wspace=0.25 , hspace=0.25)
fig.savefig('3d.pdf', format='pdf', dpi=500)

# %%
pd.set_option('display.float_format', lambda x: '%.7f' % x)

table = dict()

a = (result3d[0]['ML']['loss'][-1], result3d[1]['ML']['loss'][-1], result3d[2]['ML']['loss'][-1] , result3d[3]['ML']['loss'][-1])
b = (result3d[0]['HML']['loss'][-1], result3d[1]['HML']['loss'][-1], result3d[2]['HML']['loss'][-1] , result3d[3]['HML']['loss'][-1])
c = (result3d[0]['ML']['val_loss'][-1], result3d[1]['ML']['val_loss'][-1], result3d[2]['ML']['val_loss'][-1] , result3d[3]['ML']['val_loss'][-1])
d = (result3d[0]['HML']['val_loss'][-1], result3d[1]['HML']['val_loss'][-1], result3d[2]['HML']['val_loss'][-1] , result3d[3]['HML']['val_loss'][-1])

columns = ['3D model 1' , '3D model 2', '3D model 3' , '3D model 4']
index=['Training (ML)', 'Training (HML)', 'Validation (ML)', 'Validation (HML)']
# Create DataFrame object from a list of tuples
df = pd.DataFrame([a, b, c, d], columns = columns, index=index)

print(df.to_latex())
# Out:
# \begin{tabular}{lrrrr}
# \toprule
# {} &  3D model 1 &  3D model 2 &  3D model 3 &  3D model 4 \\
# \midrule
# Training (ML)    &   0.0000057 &   0.0000123 &   0.0000006 &   0.0000096 \\
# Training (HML)   &   0.0000068 &   0.0000057 &   0.0000002 &   0.0000125 \\
# Validation (ML)  &   1.8169936 &   1.3181295 &   1.7773948 &   0.0076983 \\
# Validation (HML) &   0.3536258 &   0.2480008 &   0.3019600 &   0.0080819 \\
# \bottomrule
# \end{tabular}

# %% [markdown]
# #### PMSE Visualization

# %%
# Before running the function below, make sure its defined parentFolder address does not need to be updated.

def abaqus(data, num_outputs = 1, header = ['S11', 'S22', 'S33'], title = 'First testing sample', script = 'Visualization.py'):
    '''a helper function to call visualization.py and update its values,
    to save each contour plot.'''
    path = 'temp_' + title.replace(' ', '_')
    data = data.reshape(-1,num_outputs)
    data = data[:,:len(header)]
    np.savetxt(path, X = data, delimiter=",")
    
    # adding the path variable in visualization.py by updaing some of its lines:
    txt = []
    with open(script, 'r') as f:
        txt = f.readlines()
        idx = txt.index('# START OF AUTOMATICALLY GENERATED PYTHON CODE\n')
        txt[idx + 1] = 'path = "%s"\n'%(path)
    
    with open(script, 'w') as f: f.writelines(txt)
    
    # run abaqus
    parentFolder = 'C:\\temp\\HybridMl\\'
    os.system('abaqus cae noGUI=' + parentFolder + 'visualization.py');
    
    lst = [i for i in os.listdir() if path == i[:len(path)] and 'png'== i[-3:]]
    img = [mpimg.imread(i)[150:-150, 200:-200, :] for i in lst]
    
    return img

# %%
# extracting contour plots for all surrogates.

data = [result3d[0]['ML']['pmse'],
        result3d[0]['HML']['pmse'],
        result3d[1]['ML']['pmse'],
        result3d[1]['HML']['pmse'],
        result3d[2]['ML']['pmse'],
        result3d[2]['HML']['pmse'],
        result3d[3]['ML']['pmse'],
        result3d[3]['HML']['pmse']]

col = header = ['ML', 'HML']
row = ['3D model 1', '3D model 2', '3D model 3', '3D model 4']

img = []
for d in data:
    img.append(abaqus(d, header = header, title = 'temp'))

# %%
# visualizing the contour plots next to one another.

plt.clf();

fig = plt.figure(figsize=(20, 23))

columns = len(col)+1
rows = len(row)+1

ax = []
for i , image in zip(range(columns*rows), img):

    ax.append(fig.add_subplot(rows, columns, (i+1+((i)//(columns-1)))))
    ax[-1].set_xticks([])
    ax[-1].set_yticks([])
    
    if i in [0 ,1]:
        ax[-1].set_title(col[i], size=14, pad=20)
        ax[-1].title.set_position([.5, 1.1])
    
    if i % 2 == 0:
        ax[-1].set_ylabel(row[i//(columns-1)], rotation=90, size=14)
        ax[-1].yaxis.labelpad = 20
    
    plt.imshow(image[0])

# adding final labels (previously generated by Abaqus):
ax.append(fig.add_subplot(8, 12, 9))
ax[-1].axis('off')
ax[-1].set_xticks([])
ax[-1].set_yticks([])
plt.imshow(mpimg.imread("mse_labels.png"))

fig.subplots_adjust(wspace=0.1 , hspace=0.03)
fig.savefig('visualization_3d.png', format='png', dpi=300)
plt.show()
